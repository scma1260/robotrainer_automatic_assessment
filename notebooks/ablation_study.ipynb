# %% [markdown]
# ## Libraries
#
# Import the necessary libraries for the evaluation of test subjects.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from itertools import combinations
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import Data
# Read CSV file and create DataFrame.

# %%
ground_truth_path = 'data/ground_truth.csv'
df = pd.read_csv(ground_truth_path)  
print(df)

kate_aa_path = 'data/KATE_AA_dataset.csv'
df_robotrainer = pd.read_csv(kate_aa_path, usecols=lambda col: col not in ["path_index_left", "path_index_front", "path_index_right", "hrv", "ppg_ch0", "ppg_ch1", "ppg_ch2", "ppg_ch3"])
print(df_robotrainer)
# Out:
#                           ID           1           2           3           4  \
# 0              Y-Balance [%]  114.502165  113.414634  103.212851  114.222222
# 1                    SLS [-]    1.000000   12.000000    4.000000    1.000000
# 2    Robotrainer [N] (vorne)  204.230000  209.660000  235.560000  201.040000
# 3    Robotrainer [N] (links)  120.350000  173.880000  164.990000  180.270000
# 4   Robotrainer [N] (rechts)  180.700000  180.530000  261.350000  216.680000
# 5           Hgrip [kg] links   30.300000   39.400000   52.800000   56.800000
# 6          Hgrip [kg] rechts   30.400000   41.200000   54.600000   64.700000
# 7                   J&R [cm]   38.000000   48.000000   36.000000   60.000000
# 8                 Tandem [s]   10.710000    7.800000   12.060000    7.650000
# 9                    F8W [s]    6.870000    4.970000    4.290000    4.290000
# 10                   SHH [-]   49.000000   37.000000   48.500000   52.000000
# 11                  TBT [cm]   23.000000   15.500000   11.333333   10.333333
# 12               Tapping [s]   10.720000   17.140000    9.790000   11.710000
# 13                Ruler [cm]   11.400000   14.000000    6.300000    9.000000
#
#              5           6           7           8           9  ...  \
# 0   107.058824  110.833333  114.529915  101.666667  107.291667  ...
# 1     5.000000    8.000000    1.000000    5.000000    3.000000  ...
# 2   245.250000   88.430000  111.490000  254.390000  268.520000  ...
# 3   154.570000  103.290000   71.720000  182.610000  172.160000  ...
# 4   172.040000  106.760000   96.820000  209.390000  246.760000  ...
# 5    27.300000   31.000000   33.600000   42.000000   57.900000  ...
# 6    33.100000   39.900000   39.700000   45.800000   58.200000  ...
# 7    36.000000   36.500000   53.000000   52.000000   51.500000  ...
# 8    16.090000   11.350000   13.270000    6.550000   14.340000  ...
# 9     4.860000    4.760000    4.220000    4.910000    5.120000  ...
# 10   49.000000   49.000000   47.000000   35.000000   44.000000  ...
# 11    8.500000   14.666667   18.833333   13.500000   16.333333  ...
# 12   10.160000   10.570000   12.650000   14.090000    8.170000  ...
# 13    3.500000   19.500000   12.000000   16.000000    5.500000  ...
#
#             19          20          21          22          23          24  \
# 0   113.178295  108.536585  105.416667   81.526104  109.126984  141.333333
# 1     1.000000    2.000000    1.000000   18.000000    4.000000    3.000000
# 2   258.650000  175.570000  186.580000  225.550000  249.380000  240.390000
# 3   241.760000  136.890000  134.410000  136.850000  130.180000  146.960000
# 4   244.260000  161.180000  149.610000  141.230000  138.160000  190.990000
# 5    48.300000   34.600000   27.000000   33.800000   51.200000   43.200000
# 6    54.800000   44.700000   30.500000   41.000000   53.700000   39.200000
# 7    47.000000   41.000000   34.000000   25.000000   39.000000   52.000000
# 8    12.880000   10.540000   11.220000    8.590000    7.400000    9.490000
# 9     4.500000    4.610000    4.590000    5.340000    4.840000    3.910000
# 10   47.500000   56.500000   49.500000   31.000000   56.000000   53.000000
# 11   17.666667   15.333333   25.333333   15.166667   14.833333   17.000000
# 12   14.480000    9.350000    8.220000   18.500000    8.790000    8.690000
# 13   12.500000   10.000000   17.000000   25.000000   16.000000    5.000000
#
#             25          26          27          28
# 0   120.833333  160.082304  128.310502  107.196970
# 1     7.000000    1.000000    4.000000    4.000000
# 2   309.620000  237.350000  174.900000  290.800000
# 3   205.040000  135.220000  212.400000  144.250000
# 4   247.730000  146.790000  225.400000  250.920000
# 5    58.200000   33.500000   41.800000   49.700000
# 6    63.900000   34.200000   56.000000   55.200000
# 7    45.500000   47.000000   45.000000   35.000000
# 8     9.100000    7.840000   10.190000    9.440000
# 9     4.000000    4.140000    4.270000    4.400000
# 10   44.000000   60.000000   56.500000   54.000000
# 11   13.666667   27.333333    9.500000   16.666667
# 12   10.290000    8.570000    7.890000    7.860000
# 13   11.000000   11.000000   15.000000   15.000000
#
# [14 rows x 29 columns]
#      user  path  time  force_input_raw_y  force_input_raw_x          ppi  \
# 0       2     8   0.0         -10.077319          93.212254          NaN
# 1       5     1   4.5           4.212586          46.885345          NaN
# 2       5     2   4.0           5.931689          52.868197  1407.500000
# 3       5     3   3.5          11.262652          59.007991  1097.333333
# 4       5     4   2.5          -1.157651          62.080021  2359.000000
# ..    ...   ...   ...                ...                ...          ...
# 463    28    16   6.0           7.879871          30.172225   906.679630
# 464    28    17   6.5          14.185067          31.171210   614.581481
# 465    28    18   6.0          -0.209474          36.628060   545.625000
# 466    28    19   6.0          -3.443169          46.423700   745.547863
# 467    28    20   6.5          -4.032119          42.308031   719.925926
#
#      robot_pose_z  robotrainer_deviation_left  robot_pose_y  \
# 0        2.843109                    0.481815      8.945766
# 1        2.898135                    0.419149     10.093447
# 2        1.859722                    0.350801     10.167159
# 3        2.005619                    0.320000     10.132463
# 4        2.845270                    0.281152     10.007904
# ..            ...                         ...           ...
# 463     -0.011168                    0.178631     10.540269
# 464     -0.103635                    0.214837     10.538270
# 465      0.512371                    0.328544     10.253969
# 466      0.521944                    0.374754     10.134815
# 467      0.408480                    0.363099     10.230154
#
#      output_data_linear_z  ...  velocity_output_linear_x  \
# 0               87.194709  ...                  0.751750
# 1              298.302037  ...                  0.814535
# 2              167.436324  ...                  0.878975
# 3              130.575519  ...                  0.926110
# 4              160.839418  ...                  1.130079
# ..                    ...  ...                       ...
# 463            269.449807  ...                  0.500609
# 464            322.455806  ...                  0.461107
# 465            349.764596  ...                  0.515209
# 466            367.793604  ...                  0.558733
# 467            359.647919  ...                  0.498334
#
#      velocity_output_linear_y  torque_input_raw_z  \
# 0                    0.000978            9.301363
# 1                   -0.043020           -1.004325
# 2                   -0.052509            2.190127
# 3                   -0.081900            3.375349
# 4                   -0.026799            0.032390
# ..                        ...                 ...
# 463                 -0.104607           -1.380340
# 464                 -0.120334            0.886709
# 465                  0.000683           -1.985529
# 466                 -0.013461           -3.092739
# 467                  0.001353           -3.483622
#
#      robotrainer_deviation_right  robotrainer_deviation_front  robot_pose_x  \
# 0                       0.495726                     0.065507      3.028799
# 1                       0.554913                     0.048722     -0.283693
# 2                       0.618678                     0.099172     -0.283044
# 3                       0.685309                     0.099311      0.065796
# 4                       0.698434                     0.191154      0.402899
# ..                           ...                          ...           ...
# 463                     0.762338                     0.138686     -0.452789
# 464                     0.769916                     0.128961     -0.146169
# 465                     0.592076                     0.092994     -0.326000
# 466                     0.584159                     0.206597     -0.570198
# 467                     0.591870                     0.220843     -0.626933
#
#      total_duration  age_x  age_y    gender
# 0          1.494377    NaN    NaN       NaN
# 1         10.010752   39.0   39.0  Weiblich
# 2          9.203966   39.0   39.0  Weiblich
# 3          8.713162   39.0   39.0  Weiblich
# 4          6.685839   39.0   39.0  Weiblich
# ..              ...    ...    ...       ...
# 463       13.815931   25.0   25.0  M�nnlich
# 464       14.651170   25.0   25.0  M�nnlich
# 465       13.713014   25.0   25.0  M�nnlich
# 466       13.314725   25.0   25.0  M�nnlich
# 467       14.300197   25.0   25.0  M�nnlich
#
# [468 rows x 38 columns]

# %% [markdown]
# 1. Prints number of rows in DataFrame
# 2. Replaces first column's values with a list of names
# 3. Sets the first column as the index of the DataFrame

# %%
print(len(df))
df.iloc[:, 0] = [
    "Balance Test", "Single Leg Stance", "Robotrainer Front", "Robotrainer Left", "Robotrainer Right",
    "Hand Grip Left", "Hand Grip Right", "Jump & Reach", "Tandem Walk", "Figure 8 Walk",
    "Jumping Sideways", "Throwing Beanbag at Target", "Tapping Test", "Ruler Drop Test"
]
df.set_index(df.columns[0], inplace=True)

print(df)
# Out:
# 14
#                                      1           2           3           4  \
# ID
# Balance Test                114.502165  113.414634  103.212851  114.222222
# Single Leg Stance             1.000000   12.000000    4.000000    1.000000
# Robotrainer Front           204.230000  209.660000  235.560000  201.040000
# Robotrainer Left            120.350000  173.880000  164.990000  180.270000
# Robotrainer Right           180.700000  180.530000  261.350000  216.680000
# Hand Grip Left               30.300000   39.400000   52.800000   56.800000
# Hand Grip Right              30.400000   41.200000   54.600000   64.700000
# Jump & Reach                 38.000000   48.000000   36.000000   60.000000
# Tandem Walk                  10.710000    7.800000   12.060000    7.650000
# Figure 8 Walk                 6.870000    4.970000    4.290000    4.290000
# Jumping Sideways             49.000000   37.000000   48.500000   52.000000
# Throwing Beanbag at Target   23.000000   15.500000   11.333333   10.333333
# Tapping Test                 10.720000   17.140000    9.790000   11.710000
# Ruler Drop Test              11.400000   14.000000    6.300000    9.000000
#
#                                      5           6           7           8  \
# ID
# Balance Test                107.058824  110.833333  114.529915  101.666667
# Single Leg Stance             5.000000    8.000000    1.000000    5.000000
# Robotrainer Front           245.250000   88.430000  111.490000  254.390000
# Robotrainer Left            154.570000  103.290000   71.720000  182.610000
# Robotrainer Right           172.040000  106.760000   96.820000  209.390000
# Hand Grip Left               27.300000   31.000000   33.600000   42.000000
# Hand Grip Right              33.100000   39.900000   39.700000   45.800000
# Jump & Reach                 36.000000   36.500000   53.000000   52.000000
# Tandem Walk                  16.090000   11.350000   13.270000    6.550000
# Figure 8 Walk                 4.860000    4.760000    4.220000    4.910000
# Jumping Sideways             49.000000   49.000000   47.000000   35.000000
# Throwing Beanbag at Target    8.500000   14.666667   18.833333   13.500000
# Tapping Test                 10.160000   10.570000   12.650000   14.090000
# Ruler Drop Test               3.500000   19.500000   12.000000   16.000000
#
#                                      9          10  ...          19  \
# ID                                                  ...
# Balance Test                107.291667  118.518518  ...  113.178295
# Single Leg Stance             3.000000    2.000000  ...    1.000000
# Robotrainer Front           268.520000  198.780000  ...  258.650000
# Robotrainer Left            172.160000  153.100000  ...  241.760000
# Robotrainer Right           246.760000  192.440000  ...  244.260000
# Hand Grip Left               57.900000   43.900000  ...   48.300000
# Hand Grip Right              58.200000   56.400000  ...   54.800000
# Jump & Reach                 51.500000   51.000000  ...   47.000000
# Tandem Walk                  14.340000    9.850000  ...   12.880000
# Figure 8 Walk                 5.120000    4.500000  ...    4.500000
# Jumping Sideways             44.000000   59.000000  ...   47.500000
# Throwing Beanbag at Target   16.333333   15.500000  ...   17.666667
# Tapping Test                  8.170000    6.920000  ...   14.480000
# Ruler Drop Test               5.500000   10.500000  ...   12.500000
#
#                                     20          21          22          23  \
# ID
# Balance Test                108.536585  105.416667   81.526104  109.126984
# Single Leg Stance             2.000000    1.000000   18.000000    4.000000
# Robotrainer Front           175.570000  186.580000  225.550000  249.380000
# Robotrainer Left            136.890000  134.410000  136.850000  130.180000
# Robotrainer Right           161.180000  149.610000  141.230000  138.160000
# Hand Grip Left               34.600000   27.000000   33.800000   51.200000
# Hand Grip Right              44.700000   30.500000   41.000000   53.700000
# Jump & Reach                 41.000000   34.000000   25.000000   39.000000
# Tandem Walk                  10.540000   11.220000    8.590000    7.400000
# Figure 8 Walk                 4.610000    4.590000    5.340000    4.840000
# Jumping Sideways             56.500000   49.500000   31.000000   56.000000
# Throwing Beanbag at Target   15.333333   25.333333   15.166667   14.833333
# Tapping Test                  9.350000    8.220000   18.500000    8.790000
# Ruler Drop Test              10.000000   17.000000   25.000000   16.000000
#
#                                     24          25          26          27  \
# ID
# Balance Test                141.333333  120.833333  160.082304  128.310502
# Single Leg Stance             3.000000    7.000000    1.000000    4.000000
# Robotrainer Front           240.390000  309.620000  237.350000  174.900000
# Robotrainer Left            146.960000  205.040000  135.220000  212.400000
# Robotrainer Right           190.990000  247.730000  146.790000  225.400000
# Hand Grip Left               43.200000   58.200000   33.500000   41.800000
# Hand Grip Right              39.200000   63.900000   34.200000   56.000000
# Jump & Reach                 52.000000   45.500000   47.000000   45.000000
# Tandem Walk                   9.490000    9.100000    7.840000   10.190000
# Figure 8 Walk                 3.910000    4.000000    4.140000    4.270000
# Jumping Sideways             53.000000   44.000000   60.000000   56.500000
# Throwing Beanbag at Target   17.000000   13.666667   27.333333    9.500000
# Tapping Test                  8.690000   10.290000    8.570000    7.890000
# Ruler Drop Test               5.000000   11.000000   11.000000   15.000000
#
#                                     28
# ID
# Balance Test                107.196970
# Single Leg Stance             4.000000
# Robotrainer Front           290.800000
# Robotrainer Left            144.250000
# Robotrainer Right           250.920000
# Hand Grip Left               49.700000
# Hand Grip Right              55.200000
# Jump & Reach                 35.000000
# Tandem Walk                   9.440000
# Figure 8 Walk                 4.400000
# Jumping Sideways             54.000000
# Throwing Beanbag at Target   16.666667
# Tapping Test                  7.860000
# Ruler Drop Test              15.000000
#
# [14 rows x 28 columns]

# %% [markdown]
# Transposes DataFrame (swapping rows and columns).

# %%
numeric_df = df.T
print(numeric_df)
numeric_df.to_csv('data/motoric_test.csv', index=True)
# Out:
# ID  Balance Test  Single Leg Stance  Robotrainer Front  Robotrainer Left  \
# 1     114.502165                1.0             204.23            120.35
# 2     113.414634               12.0             209.66            173.88
# 3     103.212851                4.0             235.56            164.99
# 4     114.222222                1.0             201.04            180.27
# 5     107.058824                5.0             245.25            154.57
# 6     110.833333                8.0              88.43            103.29
# 7     114.529915                1.0             111.49             71.72
# 8     101.666667                5.0             254.39            182.61
# 9     107.291667                3.0             268.52            172.16
# 10    118.518518                2.0             198.78            153.10
# 11    109.166667                6.0             180.39             84.83
# 12    106.172839                2.0             109.97             72.25
# 13    105.952381                2.0             274.33            131.52
# 14    114.285714                2.0             123.23             69.63
# 15    116.666667                3.0             203.97            176.37
# 16    108.658009               17.0             265.43            142.02
# 17    103.137255                8.0             221.49            153.13
# 18    100.000000                4.0             148.87            107.95
# 19    113.178295                1.0             258.65            241.76
# 20    108.536585                2.0             175.57            136.89
# 21    105.416667                1.0             186.58            134.41
# 22     81.526104               18.0             225.55            136.85
# 23    109.126984                4.0             249.38            130.18
# 24    141.333333                3.0             240.39            146.96
# 25    120.833333                7.0             309.62            205.04
# 26    160.082304                1.0             237.35            135.22
# 27    128.310502                4.0             174.90            212.40
# 28    107.196970                4.0             290.80            144.25
#
# ID  Robotrainer Right  Hand Grip Left  Hand Grip Right  Jump & Reach  \
# 1              180.70            30.3             30.4          38.0
# 2              180.53            39.4             41.2          48.0
# 3              261.35            52.8             54.6          36.0
# 4              216.68            56.8             64.7          60.0
# 5              172.04            27.3             33.1          36.0
# 6              106.76            31.0             39.9          36.5
# 7               96.82            33.6             39.7          53.0
# 8              209.39            42.0             45.8          52.0
# 9              246.76            57.9             58.2          51.5
# 10             192.44            43.9             56.4          51.0
# 11             109.79            39.2             42.0          44.0
# 12              66.77            23.5             24.5          41.5
# 13             201.90            37.6             43.5          37.5
# 14              89.87            34.0             34.2          41.5
# 15             230.66            33.7             41.7          48.5
# 16             189.39            43.3             45.4          41.0
# 17             191.56            42.7             56.0          57.0
# 18             141.85            31.3             35.6          25.0
# 19             244.26            48.3             54.8          47.0
# 20             161.18            34.6             44.7          41.0
# 21             149.61            27.0             30.5          34.0
# 22             141.23            33.8             41.0          25.0
# 23             138.16            51.2             53.7          39.0
# 24             190.99            43.2             39.2          52.0
# 25             247.73            58.2             63.9          45.5
# 26             146.79            33.5             34.2          47.0
# 27             225.40            41.8             56.0          45.0
# 28             250.92            49.7             55.2          35.0
#
# ID  Tandem Walk  Figure 8 Walk  Jumping Sideways  Throwing Beanbag at Target  \
# 1         10.71           6.87              49.0                   23.000000
# 2          7.80           4.97              37.0                   15.500000
# 3         12.06           4.29              48.5                   11.333333
# 4          7.65           4.29              52.0                   10.333333
# 5         16.09           4.86              49.0                    8.500000
# 6         11.35           4.76              49.0                   14.666667
# 7         13.27           4.22              47.0                   18.833333
# 8          6.55           4.91              35.0                   13.500000
# 9         14.34           5.12              44.0                   16.333333
# 10         9.85           4.50              59.0                   15.500000
# 11        11.76           6.28              45.0                   15.000000
# 12         9.26           4.46              50.0                   12.833333
# 13         9.89           5.11              43.0                   23.833333
# 14         9.05           4.89              57.0                   14.833333
# 15         6.64           4.24              52.0                   16.833333
# 16        12.17           4.99              40.0                   14.500000
# 17        12.15           4.64              43.0                    9.500000
# 18        12.28           5.79              37.0                   18.166667
# 19        12.88           4.50              47.5                   17.666667
# 20        10.54           4.61              56.5                   15.333333
# 21        11.22           4.59              49.5                   25.333333
# 22         8.59           5.34              31.0                   15.166667
# 23         7.40           4.84              56.0                   14.833333
# 24         9.49           3.91              53.0                   17.000000
# 25         9.10           4.00              44.0                   13.666667
# 26         7.84           4.14              60.0                   27.333333
# 27        10.19           4.27              56.5                    9.500000
# 28         9.44           4.40              54.0                   16.666667
#
# ID  Tapping Test  Ruler Drop Test
# 1          10.72             11.4
# 2          17.14             14.0
# 3           9.79              6.3
# 4          11.71              9.0
# 5          10.16              3.5
# 6          10.57             19.5
# 7          12.65             12.0
# 8          14.09             16.0
# 9           8.17              5.5
# 10          6.92             10.5
# 11         12.50             18.0
# 12         10.65             12.5
# 13         10.92             20.0
# 14          9.35             14.0
# 15          9.35             11.0
# 16          9.65             13.5
# 17         57.00              7.5
# 18          9.95             17.0
# 19         14.48             12.5
# 20          9.35             10.0
# 21          8.22             17.0
# 22         18.50             25.0
# 23          8.79             16.0
# 24          8.69              5.0
# 25         10.29             11.0
# 26          8.57             11.0
# 27          7.89             15.0
# 28          7.86             15.0

# %% [markdown]
# ## Pearson Correlation Coefficient
# The Pearson correlation measures the linear relationship between two variables. It returns a value between -1 and 1:
#
# - 1: Perfect positive correlation.
# - -1: Perfect negative correlation.
# - 0: No linear correlation.

# %%
correlation_matrix = numeric_df.corr(method='pearson')
print(correlation_matrix)
# Out:
# ID                          Balance Test  Single Leg Stance  \
# ID
# Balance Test                    1.000000          -0.398402
# Single Leg Stance              -0.398402           1.000000
# Robotrainer Front               0.047931           0.181189
# Robotrainer Left                0.127138           0.056483
# Robotrainer Right               0.060462          -0.024158
# Hand Grip Left                  0.058652           0.031534
# Hand Grip Right                -0.025830           0.052744
# Jump & Reach                    0.441906          -0.270069
# Tandem Walk                    -0.212451          -0.023090
# Figure 8 Walk                  -0.409233           0.178262
# Jumping Sideways                0.618960          -0.645249
# Throwing Beanbag at Target      0.315311          -0.306852
# Tapping Test                   -0.248650           0.287849
# Ruler Drop Test                -0.383533           0.364534
#
# ID                          Robotrainer Front  Robotrainer Left  \
# ID
# Balance Test                         0.047931          0.127138
# Single Leg Stance                    0.181189          0.056483
# Robotrainer Front                    1.000000          0.632731
# Robotrainer Left                     0.632731          1.000000
# Robotrainer Right                    0.748633          0.853561
# Hand Grip Left                       0.616108          0.583174
# Hand Grip Right                      0.501549          0.649622
# Jump & Reach                         0.077866          0.307646
# Tandem Walk                         -0.063671         -0.087899
# Figure 8 Walk                       -0.105153         -0.344802
# Jumping Sideways                    -0.178660         -0.071798
# Throwing Beanbag at Target           0.042393         -0.233995
# Tapping Test                         0.031846          0.062774
# Ruler Drop Test                     -0.205484         -0.267528
#
# ID                          Robotrainer Right  Hand Grip Left  \
# ID
# Balance Test                         0.060462        0.058652
# Single Leg Stance                   -0.024158        0.031534
# Robotrainer Front                    0.748633        0.616108
# Robotrainer Left                     0.853561        0.583174
# Robotrainer Right                    1.000000        0.698698
# Hand Grip Left                       0.698698        1.000000
# Hand Grip Right                      0.701351        0.914789
# Jump & Reach                         0.241316        0.413010
# Tandem Walk                         -0.007487       -0.086370
# Figure 8 Walk                       -0.257361       -0.279756
# Jumping Sideways                    -0.045199        0.011576
# Throwing Beanbag at Target          -0.150573       -0.308368
# Tapping Test                         0.007427        0.022152
# Ruler Drop Test                     -0.367780       -0.286708
#
# ID                          Hand Grip Right  Jump & Reach  Tandem Walk  \
# ID
# Balance Test                      -0.025830      0.441906    -0.212451
# Single Leg Stance                  0.052744     -0.270069    -0.023090
# Robotrainer Front                  0.501549      0.077866    -0.063671
# Robotrainer Left                   0.649622      0.307646    -0.087899
# Robotrainer Right                  0.701351      0.241316    -0.007487
# Hand Grip Left                     0.914789      0.413010    -0.086370
# Hand Grip Right                    1.000000      0.422162    -0.057448
# Jump & Reach                       0.422162      1.000000    -0.163505
# Tandem Walk                       -0.057448     -0.163505     1.000000
# Figure 8 Walk                     -0.336866     -0.400986     0.202836
# Jumping Sideways                   0.046344      0.221656    -0.113191
# Throwing Beanbag at Target        -0.427124     -0.207326    -0.124797
# Tapping Test                       0.162578      0.284969     0.103574
# Ruler Drop Test                   -0.205134     -0.527257    -0.327815
#
# ID                          Figure 8 Walk  Jumping Sideways  \
# ID
# Balance Test                    -0.409233          0.618960
# Single Leg Stance                0.178262         -0.645249
# Robotrainer Front               -0.105153         -0.178660
# Robotrainer Left                -0.344802         -0.071798
# Robotrainer Right               -0.257361         -0.045199
# Hand Grip Left                  -0.279756          0.011576
# Hand Grip Right                 -0.336866          0.046344
# Jump & Reach                    -0.400986          0.221656
# Tandem Walk                      0.202836         -0.113191
# Figure 8 Walk                    1.000000         -0.401730
# Jumping Sideways                -0.401730          1.000000
# Throwing Beanbag at Target       0.191464          0.090468
# Tapping Test                     0.039821         -0.337004
# Ruler Drop Test                  0.353731         -0.369457
#
# ID                          Throwing Beanbag at Target  Tapping Test  \
# ID
# Balance Test                                  0.315311     -0.248650
# Single Leg Stance                            -0.306852      0.287849
# Robotrainer Front                             0.042393      0.031846
# Robotrainer Left                             -0.233995      0.062774
# Robotrainer Right                            -0.150573      0.007427
# Hand Grip Left                               -0.308368      0.022152
# Hand Grip Right                              -0.427124      0.162578
# Jump & Reach                                 -0.207326      0.284969
# Tandem Walk                                  -0.124797      0.103574
# Figure 8 Walk                                 0.191464      0.039821
# Jumping Sideways                              0.090468     -0.337004
# Throwing Beanbag at Target                    1.000000     -0.288168
# Tapping Test                                 -0.288168      1.000000
# Ruler Drop Test                               0.282808     -0.080884
#
# ID                          Ruler Drop Test
# ID
# Balance Test                      -0.383533
# Single Leg Stance                  0.364534
# Robotrainer Front                 -0.205484
# Robotrainer Left                  -0.267528
# Robotrainer Right                 -0.367780
# Hand Grip Left                    -0.286708
# Hand Grip Right                   -0.205134
# Jump & Reach                      -0.527257
# Tandem Walk                       -0.327815
# Figure 8 Walk                      0.353731
# Jumping Sideways                  -0.369457
# Throwing Beanbag at Target         0.282808
# Tapping Test                      -0.080884
# Ruler Drop Test                    1.000000

# %%
correlation_matrix_robo = df_robotrainer.select_dtypes(include=[np.number]).corr(method='pearson')
print(correlation_matrix_robo)
# Out:
#                                         user      path      time  \
# user                                1.000000 -0.005871 -0.061108
# path                               -0.005871  1.000000  0.284946
# time                               -0.061108  0.284946  1.000000
# force_input_raw_y                   0.154867  0.078081 -0.090593
# force_input_raw_x                   0.021107 -0.433779 -0.557349
# ppi                                -0.081880  0.018700  0.007590
# robot_pose_z                        0.059358 -0.803767 -0.507911
# robotrainer_deviation_left          0.021677 -0.286423 -0.137510
# robot_pose_y                       -0.076691  0.513930  0.215631
# output_data_linear_z               -0.003026  0.210819 -0.243561
# velocity_output_angular_z           0.011425 -0.121505  0.243853
# output_data_linear_x                0.021368 -0.433624 -0.557243
# virtual_force_resulting_force_y    -0.034218 -0.093210 -0.232461
# virtual_force_resulting_force_x     0.138556 -0.598224 -0.501325
# output_data_angular_y              -0.000244 -0.131273  0.324269
# output_data_angular_z              -0.013396 -0.289429 -0.063456
# heart_rate                          0.067444 -0.027457 -0.009614
# virtual_force_position_x            0.013054 -0.626663 -0.601499
# virtual_force_position_y           -0.087819  0.705537  0.582912
# virtual_force_velocity_out_y        0.110767 -0.094750 -0.231913
# virtual_force_velocity_out_x        0.117930 -0.685108 -0.893275
# force_input_scaled_limited_y        0.160650  0.058596 -0.094883
# force_input_scaled_limited_x        0.070139 -0.554799 -0.705268
# torque_input_scaled_limited_z      -0.017132 -0.145120 -0.148793
# virtual_force_resulting_velocity_x  0.138616 -0.600340 -0.501198
# virtual_force_resulting_velocity_y -0.033732 -0.092420 -0.232875
# virtual_force_velocity_in_y         0.151501  0.063628  0.131030
# virtual_force_velocity_in_x         0.107785 -0.632080 -0.878286
# velocity_output_linear_x            0.094804 -0.625358 -0.719233
# velocity_output_linear_y            0.108352 -0.106837 -0.086183
# torque_input_raw_z                 -0.014212 -0.290893 -0.064791
# robotrainer_deviation_right        -0.116010  0.201596 -0.095085
# robotrainer_deviation_front        -0.062843  0.216856  0.359968
# robot_pose_x                        0.023824 -0.531054 -0.429595
# total_duration                     -0.060799  0.285985  0.999638
# age_x                               0.077405 -0.002993  0.029967
# age_y                               0.077405 -0.002993  0.029967
#
#                                     force_input_raw_y  force_input_raw_x  \
# user                                         0.154867           0.021107
# path                                         0.078081          -0.433779
# time                                        -0.090593          -0.557349
# force_input_raw_y                            1.000000          -0.017289
# force_input_raw_x                           -0.017289           1.000000
# ppi                                          0.077283          -0.082141
# robot_pose_z                                -0.095175           0.559941
# robotrainer_deviation_left                  -0.141807           0.283206
# robot_pose_y                                 0.149886          -0.409139
# output_data_linear_z                         0.121487           0.051589
# velocity_output_angular_z                   -0.164606          -0.231448
# output_data_linear_x                        -0.017493           0.999992
# virtual_force_resulting_force_y             -0.656011           0.278970
# virtual_force_resulting_force_x             -0.022136           0.312192
# output_data_angular_y                       -0.137725          -0.201498
# output_data_angular_z                        0.233110           0.133659
# heart_rate                                  -0.122987           0.152341
# virtual_force_position_x                    -0.106484           0.576071
# virtual_force_position_y                     0.176869          -0.499214
# virtual_force_velocity_out_y                -0.013066           0.305771
# virtual_force_velocity_out_x                -0.178556           0.844441
# force_input_scaled_limited_y                 0.989408          -0.006998
# force_input_scaled_limited_x                 0.003012           0.916433
# torque_input_scaled_limited_z                0.292970           0.120940
# virtual_force_resulting_velocity_x          -0.024341           0.313504
# virtual_force_resulting_velocity_y          -0.655369           0.278999
# virtual_force_velocity_in_y                  0.909370          -0.111192
# virtual_force_velocity_in_x                 -0.184281           0.860766
# velocity_output_linear_x                    -0.001432           0.867334
# velocity_output_linear_y                     0.059405           0.263362
# torque_input_raw_z                           0.232723           0.134123
# robotrainer_deviation_right                  0.164905          -0.010775
# robotrainer_deviation_front                 -0.044220          -0.143289
# robot_pose_x                                 0.011202           0.591515
# total_duration                              -0.089964          -0.557474
# age_x                                       -0.096449          -0.058663
# age_y                                       -0.096449          -0.058663
#
#                                          ppi  robot_pose_z  \
# user                               -0.081880      0.059358
# path                                0.018700     -0.803767
# time                                0.007590     -0.507911
# force_input_raw_y                   0.077283     -0.095175
# force_input_raw_x                  -0.082141      0.559941
# ppi                                 1.000000     -0.020518
# robot_pose_z                       -0.020518      1.000000
# robotrainer_deviation_left         -0.090088      0.424669
# robot_pose_y                        0.075784     -0.670896
# output_data_linear_z                0.055618     -0.083875
# velocity_output_angular_z           0.033456     -0.143196
# output_data_linear_x               -0.082200      0.559766
# virtual_force_resulting_force_y    -0.120004      0.364999
# virtual_force_resulting_force_x    -0.081475      0.574384
# output_data_angular_y              -0.043585     -0.010006
# output_data_angular_z               0.012169      0.256169
# heart_rate                         -0.303091      0.049725
# virtual_force_position_x           -0.048518      0.529417
# virtual_force_position_y            0.044471     -0.786397
# virtual_force_velocity_out_y       -0.111946      0.409283
# virtual_force_velocity_out_x       -0.103071      0.726492
# force_input_scaled_limited_y        0.070355     -0.080413
# force_input_scaled_limited_x       -0.087335      0.715771
# torque_input_scaled_limited_z       0.048620      0.187854
# virtual_force_resulting_velocity_x -0.081103      0.577332
# virtual_force_resulting_velocity_y -0.120623      0.364203
# virtual_force_velocity_in_y         0.055555     -0.137003
# virtual_force_velocity_in_x        -0.097884      0.682346
# velocity_output_linear_x           -0.072403      0.767211
# velocity_output_linear_y           -0.101103      0.380460
# torque_input_raw_z                  0.013289      0.257779
# robotrainer_deviation_right         0.043800     -0.313364
# robotrainer_deviation_front        -0.031556     -0.326286
# robot_pose_x                       -0.080537      0.534436
# total_duration                      0.006154     -0.509135
# age_x                               0.048016     -0.015880
# age_y                               0.048016     -0.015880
#
#                                     robotrainer_deviation_left  robot_pose_y  \
# user                                                  0.021677     -0.076691
# path                                                 -0.286423      0.513930
# time                                                 -0.137510      0.215631
# force_input_raw_y                                    -0.141807      0.149886
# force_input_raw_x                                     0.283206     -0.409139
# ppi                                                  -0.090088      0.075784
# robot_pose_z                                          0.424669     -0.670896
# robotrainer_deviation_left                            1.000000     -0.682765
# robot_pose_y                                         -0.682765      1.000000
# output_data_linear_z                                 -0.011706      0.144548
# velocity_output_angular_z                            -0.144955      0.035002
# output_data_linear_x                                  0.282897     -0.408754
# virtual_force_resulting_force_y                       0.644977     -0.594188
# virtual_force_resulting_force_x                       0.119330     -0.259384
# output_data_angular_y                                -0.032795     -0.078967
# output_data_angular_z                                 0.091847     -0.103443
# heart_rate                                            0.090934     -0.067802
# virtual_force_position_x                              0.096753     -0.419209
# virtual_force_position_y                             -0.588368      0.917728
# virtual_force_velocity_out_y                          0.694964     -0.668801
# virtual_force_velocity_out_x                          0.371603     -0.542864
# force_input_scaled_limited_y                         -0.133964      0.146241
# force_input_scaled_limited_x                          0.291560     -0.471498
# torque_input_scaled_limited_z                         0.021878      0.030716
# virtual_force_resulting_velocity_x                    0.120406     -0.262572
# virtual_force_resulting_velocity_y                    0.645519     -0.593892
# virtual_force_velocity_in_y                          -0.180900      0.161517
# virtual_force_velocity_in_x                           0.371665     -0.532710
# velocity_output_linear_x                              0.293720     -0.447291
# velocity_output_linear_y                              0.630687     -0.629394
# torque_input_raw_z                                    0.092512     -0.103079
# robotrainer_deviation_right                          -0.544123      0.735746
# robotrainer_deviation_front                           0.064342      0.263240
# robot_pose_x                                         -0.002345     -0.333242
# total_duration                                       -0.138619      0.214746
# age_x                                                -0.094739      0.122185
# age_y                                                -0.094739      0.122185
#
#                                     output_data_linear_z  ...  \
# user                                           -0.003026  ...
# path                                            0.210819  ...
# time                                           -0.243561  ...
# force_input_raw_y                               0.121487  ...
# force_input_raw_x                               0.051589  ...
# ppi                                             0.055618  ...
# robot_pose_z                                   -0.083875  ...
# robotrainer_deviation_left                     -0.011706  ...
# robot_pose_y                                    0.144548  ...
# output_data_linear_z                            1.000000  ...
# velocity_output_angular_z                      -0.184417  ...
# output_data_linear_x                            0.051305  ...
# virtual_force_resulting_force_y                -0.053235  ...
# virtual_force_resulting_force_x                -0.158901  ...
# output_data_angular_y                          -0.987333  ...
# output_data_angular_z                          -0.141947  ...
# heart_rate                                      0.047701  ...
# virtual_force_position_x                       -0.205564  ...
# virtual_force_position_y                        0.178548  ...
# virtual_force_velocity_out_y                   -0.059181  ...
# virtual_force_velocity_out_x                   -0.184607  ...
# force_input_scaled_limited_y                    0.110097  ...
# force_input_scaled_limited_x                    0.022284  ...
# torque_input_scaled_limited_z                   0.053371  ...
# virtual_force_resulting_velocity_x             -0.161978  ...
# virtual_force_resulting_velocity_y             -0.052598  ...
# virtual_force_velocity_in_y                     0.015052  ...
# virtual_force_velocity_in_x                    -0.171490  ...
# velocity_output_linear_x                        0.034816  ...
# velocity_output_linear_y                       -0.067462  ...
# torque_input_raw_z                             -0.142622  ...
# robotrainer_deviation_right                     0.174017  ...
# robotrainer_deviation_front                    -0.017803  ...
# robot_pose_x                                   -0.119256  ...
# total_duration                                 -0.244687  ...
# age_x                                           0.201241  ...
# age_y                                           0.201241  ...
#
#                                     virtual_force_velocity_in_x  \
# user                                                   0.107785
# path                                                  -0.632080
# time                                                  -0.878286
# force_input_raw_y                                     -0.184281
# force_input_raw_x                                      0.860766
# ppi                                                   -0.097884
# robot_pose_z                                           0.682346
# robotrainer_deviation_left                             0.371665
# robot_pose_y                                          -0.532710
# output_data_linear_z                                  -0.171490
# velocity_output_angular_z                              0.020618
# output_data_linear_x                                   0.860899
# virtual_force_resulting_force_y                        0.318566
# virtual_force_resulting_force_x                        0.410314
# output_data_angular_y                                  0.056448
# output_data_angular_z                                  0.120367
# heart_rate                                             0.149916
# virtual_force_position_x                               0.651691
# virtual_force_position_y                              -0.614172
# virtual_force_velocity_out_y                           0.333567
# virtual_force_velocity_out_x                           0.989906
# force_input_scaled_limited_y                          -0.176259
# force_input_scaled_limited_x                           0.965463
# torque_input_scaled_limited_z                         -0.030418
# virtual_force_resulting_velocity_x                     0.411624
# virtual_force_resulting_velocity_y                     0.318402
# virtual_force_velocity_in_y                           -0.143936
# virtual_force_velocity_in_x                            1.000000
# velocity_output_linear_x                               0.989910
# velocity_output_linear_y                               0.333467
# torque_input_raw_z                                     0.122800
# robotrainer_deviation_right                           -0.139711
# robotrainer_deviation_front                            0.143634
# robot_pose_x                                           0.601559
# total_duration                                        -0.879739
# age_x                                                  0.010380
# age_y                                                  0.010380
#
#                                     velocity_output_linear_x  \
# user                                                0.094804
# path                                               -0.625358
# time                                               -0.719233
# force_input_raw_y                                  -0.001432
# force_input_raw_x                                   0.867334
# ppi                                                -0.072403
# robot_pose_z                                        0.767211
# robotrainer_deviation_left                          0.293720
# robot_pose_y                                       -0.447291
# output_data_linear_z                                0.034816
# velocity_output_angular_z                          -0.248229
# output_data_linear_x                                0.867302
# virtual_force_resulting_force_y                     0.291483
# virtual_force_resulting_force_x                     0.532551
# output_data_angular_y                              -0.168857
# output_data_angular_z                               0.191309
# heart_rate                                          0.090041
# virtual_force_position_x                            0.666295
# virtual_force_position_y                           -0.628250
# virtual_force_velocity_out_y                        0.309950
# virtual_force_velocity_out_x                        1.000000
# force_input_scaled_limited_y                        0.010349
# force_input_scaled_limited_x                        0.973731
# torque_input_scaled_limited_z                       0.187387
# virtual_force_resulting_velocity_x                  0.533775
# virtual_force_resulting_velocity_y                  0.291286
# virtual_force_velocity_in_y                        -0.134542
# virtual_force_velocity_in_x                         0.989910
# velocity_output_linear_x                            1.000000
# velocity_output_linear_y                            0.255745
# torque_input_raw_z                                  0.193259
# robotrainer_deviation_right                        -0.002252
# robotrainer_deviation_front                        -0.212120
# robot_pose_x                                        0.618550
# total_duration                                     -0.720459
# age_x                                               0.002827
# age_y                                               0.002827
#
#                                     velocity_output_linear_y  \
# user                                                0.108352
# path                                               -0.106837
# time                                               -0.086183
# force_input_raw_y                                   0.059405
# force_input_raw_x                                   0.263362
# ppi                                                -0.101103
# robot_pose_z                                        0.380460
# robotrainer_deviation_left                          0.630687
# robot_pose_y                                       -0.629394
# output_data_linear_z                               -0.067462
# velocity_output_angular_z                          -0.248059
# output_data_linear_x                                0.263203
# virtual_force_resulting_force_y                     0.667460
# virtual_force_resulting_force_x                    -0.041236
# output_data_angular_y                               0.019800
# output_data_angular_z                               0.159679
# heart_rate                                          0.096566
# virtual_force_position_x                            0.083323
# virtual_force_position_y                           -0.506581
# virtual_force_velocity_out_y                        0.999996
# virtual_force_velocity_out_x                        0.309909
# force_input_scaled_limited_y                        0.061974
# force_input_scaled_limited_x                        0.260423
# torque_input_scaled_limited_z                       0.050739
# virtual_force_resulting_velocity_x                 -0.039246
# virtual_force_resulting_velocity_y                  0.666860
# virtual_force_velocity_in_y                         0.077576
# virtual_force_velocity_in_x                         0.333467
# velocity_output_linear_x                            0.255745
# velocity_output_linear_y                            1.000000
# torque_input_raw_z                                  0.159615
# robotrainer_deviation_right                        -0.582877
# robotrainer_deviation_front                        -0.051628
# robot_pose_x                                        0.064870
# total_duration                                     -0.086857
# age_x                                              -0.112696
# age_y                                              -0.112696
#
#                                     torque_input_raw_z  \
# user                                         -0.014212
# path                                         -0.290893
# time                                         -0.064791
# force_input_raw_y                             0.232723
# force_input_raw_x                             0.134123
# ppi                                           0.013289
# robot_pose_z                                  0.257779
# robotrainer_deviation_left                    0.092512
# robot_pose_y                                 -0.103079
# output_data_linear_z                         -0.142622
# velocity_output_angular_z                    -0.391690
# output_data_linear_x                          0.134228
# virtual_force_resulting_force_y              -0.095752
# virtual_force_resulting_force_x               0.156835
# output_data_angular_y                         0.073538
# output_data_angular_z                         0.999623
# heart_rate                                   -0.051504
# virtual_force_position_x                      0.314036
# virtual_force_position_y                     -0.286051
# virtual_force_velocity_out_y                  0.182393
# virtual_force_velocity_out_x                  0.144973
# force_input_scaled_limited_y                  0.242919
# force_input_scaled_limited_x                  0.189407
# torque_input_scaled_limited_z                 0.870344
# virtual_force_resulting_velocity_x            0.157248
# virtual_force_resulting_velocity_y           -0.095713
# virtual_force_velocity_in_y                   0.338550
# virtual_force_velocity_in_x                   0.122800
# velocity_output_linear_x                      0.193259
# velocity_output_linear_y                      0.159615
# torque_input_raw_z                            1.000000
# robotrainer_deviation_right                   0.023605
# robotrainer_deviation_front                  -0.131052
# robot_pose_x                                  0.274771
# total_duration                               -0.064542
# age_x                                        -0.054247
# age_y                                        -0.054247
#
#                                     robotrainer_deviation_right  \
# user                                                  -0.116010
# path                                                   0.201596
# time                                                  -0.095085
# force_input_raw_y                                      0.164905
# force_input_raw_x                                     -0.010775
# ppi                                                    0.043800
# robot_pose_z                                          -0.313364
# robotrainer_deviation_left                            -0.544123
# robot_pose_y                                           0.735746
# output_data_linear_z                                   0.174017
# velocity_output_angular_z                             -0.118844
# output_data_linear_x                                  -0.010287
# virtual_force_resulting_force_y                       -0.553771
# virtual_force_resulting_force_x                        0.017918
# output_data_angular_y                                 -0.171937
# output_data_angular_z                                  0.022726
# heart_rate                                            -0.081653
# virtual_force_position_x                               0.045064
# virtual_force_position_y                               0.624080
# virtual_force_velocity_out_y                          -0.624743
# virtual_force_velocity_out_x                          -0.136497
# force_input_scaled_limited_y                           0.165489
# force_input_scaled_limited_x                          -0.037687
# torque_input_scaled_limited_z                          0.144750
# virtual_force_resulting_velocity_x                     0.015159
# virtual_force_resulting_velocity_y                    -0.553774
# virtual_force_velocity_in_y                            0.144871
# virtual_force_velocity_in_x                           -0.139711
# velocity_output_linear_x                              -0.002252
# velocity_output_linear_y                              -0.582877
# torque_input_raw_z                                     0.023605
# robotrainer_deviation_right                            1.000000
# robotrainer_deviation_front                            0.376114
# robot_pose_x                                           0.095259
# total_duration                                        -0.093200
# age_x                                                  0.194453
# age_y                                                  0.194453
#
#                                     robotrainer_deviation_front  robot_pose_x  \
# user                                                  -0.062843      0.023824
# path                                                   0.216856     -0.531054
# time                                                   0.359968     -0.429595
# force_input_raw_y                                     -0.044220      0.011202
# force_input_raw_x                                     -0.143289      0.591515
# ppi                                                   -0.031556     -0.080537
# robot_pose_z                                          -0.326286      0.534436
# robotrainer_deviation_left                             0.064342     -0.002345
# robot_pose_y                                           0.263240     -0.333242
# output_data_linear_z                                  -0.017803     -0.119256
# velocity_output_angular_z                              0.203382      0.022064
# output_data_linear_x                                  -0.142861      0.591464
# virtual_force_resulting_force_y                       -0.068382      0.024895
# virtual_force_resulting_force_x                        0.086223      0.437130
# output_data_angular_y                                  0.044369      0.019126
# output_data_angular_z                                 -0.132207      0.274572
# heart_rate                                            -0.027481      0.071775
# virtual_force_position_x                               0.096178      0.905914
# virtual_force_position_y                               0.230190     -0.514389
# virtual_force_velocity_out_y                          -0.037128      0.062154
# virtual_force_velocity_out_x                           0.138824      0.623157
# force_input_scaled_limited_y                          -0.046269      0.009704
# force_input_scaled_limited_x                          -0.268633      0.641506
# torque_input_scaled_limited_z                         -0.169643      0.209787
# virtual_force_resulting_velocity_x                     0.084418      0.438523
# virtual_force_resulting_velocity_y                    -0.067951      0.024225
# virtual_force_velocity_in_y                            0.072414      0.013409
# virtual_force_velocity_in_x                            0.143634      0.601559
# velocity_output_linear_x                              -0.212120      0.618550
# velocity_output_linear_y                              -0.051628      0.064870
# torque_input_raw_z                                    -0.131052      0.274771
# robotrainer_deviation_right                            0.376114      0.095259
# robotrainer_deviation_front                            1.000000     -0.188612
# robot_pose_x                                          -0.188612      1.000000
# total_duration                                         0.361678     -0.423417
# age_x                                                  0.075961     -0.024684
# age_y                                                  0.075961     -0.024684
#
#                                     total_duration     age_x     age_y
# user                                     -0.060799  0.077405  0.077405
# path                                      0.285985 -0.002993 -0.002993
# time                                      0.999638  0.029967  0.029967
# force_input_raw_y                        -0.089964 -0.096449 -0.096449
# force_input_raw_x                        -0.557474 -0.058663 -0.058663
# ppi                                       0.006154  0.048016  0.048016
# robot_pose_z                             -0.509135 -0.015880 -0.015880
# robotrainer_deviation_left               -0.138619 -0.094739 -0.094739
# robot_pose_y                              0.214746  0.122185  0.122185
# output_data_linear_z                     -0.244687  0.201241  0.201241
# velocity_output_angular_z                 0.245964  0.024274  0.024274
# output_data_linear_x                     -0.557365 -0.058400 -0.058400
# virtual_force_resulting_force_y          -0.234485  0.020865  0.020865
# virtual_force_resulting_force_x          -0.507190  0.041060  0.041060
# output_data_angular_y                     0.325382 -0.186065 -0.186065
# output_data_angular_z                    -0.063168 -0.054753 -0.054753
# heart_rate                               -0.009948 -0.160693 -0.160693
# virtual_force_position_x                 -0.580660  0.059193  0.059193
# virtual_force_position_y                  0.577528  0.110438  0.110438
# virtual_force_velocity_out_y             -0.232461 -0.116223 -0.116223
# virtual_force_velocity_out_x             -0.895590  0.016169  0.016169
# force_input_scaled_limited_y             -0.094542 -0.110982 -0.110982
# force_input_scaled_limited_x             -0.706121 -0.030332 -0.030332
# torque_input_scaled_limited_z            -0.149299 -0.056839 -0.056839
# virtual_force_resulting_velocity_x       -0.507073  0.040934  0.040934
# virtual_force_resulting_velocity_y       -0.234917  0.020972  0.020972
# virtual_force_velocity_in_y               0.135567 -0.157715 -0.157715
# virtual_force_velocity_in_x              -0.879739  0.010380  0.010380
# velocity_output_linear_x                 -0.720459  0.002827  0.002827
# velocity_output_linear_y                 -0.086857 -0.112696 -0.112696
# torque_input_raw_z                       -0.064542 -0.054247 -0.054247
# robotrainer_deviation_right              -0.093200  0.194453  0.194453
# robotrainer_deviation_front               0.361678  0.075961  0.075961
# robot_pose_x                             -0.423417 -0.024684 -0.024684
# total_duration                            1.000000  0.028454  0.028454
# age_x                                     0.028454  1.000000  1.000000
# age_y                                     0.028454  1.000000  1.000000
#
# [37 rows x 37 columns]

# %% [markdown]
# ### Heatmap

# %%
custom_cmap = LinearSegmentedColormap.from_list("custom_reds", ['#ffffff', '#c00000'])

plt.figure(figsize=(8.27, 6))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap=custom_cmap,  
    cbar=True,
    annot_kws={"size": 8}
)

plt.title("Pearson Correlation Heatmap", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig('figures/pearson_ground_truth.pdf', format='pdf')

plt.show()

# %%
custom_cmap = LinearSegmentedColormap.from_list("custom_reds", ['#ffffff', '#c00000'])

rows, cols = correlation_matrix_robo.shape

fig_width = max(6, cols * 0.6)
fig_height = max(4, rows * 0.6)

plt.figure(figsize=(fig_width, fig_height))

sns.heatmap(
    correlation_matrix_robo,
    annot=True,
    fmt=".2f",
    cmap=custom_cmap,
    cbar=True,
    annot_kws={"size": 8}
)

plt.title("Pearson Correlation Heatmap", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout() 
plt.savefig('figures/pearson_robotrainer.pdf', format='pdf')
plt.show()

# %% [markdown]
# ## Spearman Correlation
# The Spearman correlation measures the monotonic relationship between two variables. It is based on the rank values of the data rather than the actual data values.
# - 1: Perfect positive monotonic relationship.
# - -1: Perfect negative monotonic relationship.
# - 0: No monotonic relationship.

# %%
spearman_correlation_matrix = numeric_df.corr(method='spearman')
print(spearman_correlation_matrix)
# Out:
# ID                          Balance Test  Single Leg Stance  \
# ID
# Balance Test                    1.000000          -0.333493
# Single Leg Stance              -0.333493           1.000000
# Robotrainer Front              -0.102354           0.208398
# Robotrainer Left                0.131910           0.164117
# Robotrainer Right               0.063492           0.028783
# Hand Grip Left                  0.126984           0.179892
# Hand Grip Right                 0.064604           0.200150
# Jump & Reach                    0.484525          -0.193335
# Tandem Walk                    -0.223864          -0.009963
# Figure 8 Walk                  -0.539009           0.313929
# Jumping Sideways                0.570216          -0.535632
# Throwing Beanbag at Target      0.182341          -0.525363
# Tapping Test                   -0.325301           0.251156
# Ruler Drop Test                -0.309084           0.231793
#
# ID                          Robotrainer Front  Robotrainer Left  \
# ID
# Balance Test                        -0.102354          0.131910
# Single Leg Stance                    0.208398          0.164117
# Robotrainer Front                    1.000000          0.504652
# Robotrainer Left                     0.504652          1.000000
# Robotrainer Right                    0.639847          0.827586
# Hand Grip Left                       0.590038          0.583470
# Hand Grip Right                      0.429510          0.653983
# Jump & Reach                         0.019447          0.388387
# Tandem Walk                         -0.060208         -0.131363
# Figure 8 Walk                        0.011771         -0.322201
# Jumping Sideways                    -0.270448         -0.107138
# Throwing Beanbag at Target           0.049281         -0.313484
# Tapping Test                        -0.043264         -0.005476
# Ruler Drop Test                     -0.167968         -0.401425
#
# ID                          Robotrainer Right  Hand Grip Left  \
# ID
# Balance Test                         0.063492        0.126984
# Single Leg Stance                    0.028783        0.179892
# Robotrainer Front                    0.639847        0.590038
# Robotrainer Left                     0.827586        0.583470
# Robotrainer Right                    1.000000        0.681992
# Hand Grip Left                       0.681992        1.000000
# Hand Grip Right                      0.705174        0.889680
# Jump & Reach                         0.218844        0.377157
# Tandem Walk                         -0.007663       -0.107280
# Figure 8 Walk                       -0.284971       -0.203121
# Jumping Sideways                    -0.069325       -0.042198
# Throwing Beanbag at Target          -0.100753       -0.267488
# Tapping Test                        -0.185104       -0.123768
# Ruler Drop Test                     -0.381696       -0.287985
#
# ID                          Hand Grip Right  Jump & Reach  Tandem Walk  \
# ID
# Balance Test                       0.064604      0.484525    -0.223864
# Single Leg Stance                  0.200150     -0.193335    -0.009963
# Robotrainer Front                  0.429510      0.019447    -0.060208
# Robotrainer Left                   0.653983      0.388387    -0.131363
# Robotrainer Right                  0.705174      0.218844    -0.007663
# Hand Grip Left                     0.889680      0.377157    -0.107280
# Hand Grip Right                    1.000000      0.394521    -0.053928
# Jump & Reach                       0.394521      1.000000    -0.184881
# Tandem Walk                       -0.053928     -0.184881     1.000000
# Figure 8 Walk                     -0.190854     -0.386301     0.220914
# Jumping Sideways                  -0.054543      0.073769    -0.246609
# Throwing Beanbag at Target        -0.359441     -0.108919     0.037235
# Tapping Test                      -0.074226      0.154289     0.030668
# Ruler Drop Test                   -0.206934     -0.484986    -0.195643
#
# ID                          Figure 8 Walk  Jumping Sideways  \
# ID
# Balance Test                    -0.539009          0.570216
# Single Leg Stance                0.313929         -0.535632
# Robotrainer Front                0.011771         -0.270448
# Robotrainer Left                -0.322201         -0.107138
# Robotrainer Right               -0.284971         -0.069325
# Hand Grip Left                  -0.203121         -0.042198
# Hand Grip Right                 -0.190854         -0.054543
# Jump & Reach                    -0.386301          0.073769
# Tandem Walk                      0.220914         -0.246609
# Figure 8 Walk                    1.000000         -0.529944
# Jumping Sideways                -0.529944          1.000000
# Throwing Beanbag at Target       0.049432          0.059896
# Tapping Test                     0.321008         -0.691433
# Ruler Drop Test                  0.445800         -0.291770
#
# ID                          Throwing Beanbag at Target  Tapping Test  \
# ID
# Balance Test                                  0.182341     -0.325301
# Single Leg Stance                            -0.525363      0.251156
# Robotrainer Front                             0.049281     -0.043264
# Robotrainer Left                             -0.313484     -0.005476
# Robotrainer Right                            -0.100753     -0.185104
# Hand Grip Left                               -0.267488     -0.123768
# Hand Grip Right                              -0.359441     -0.074226
# Jump & Reach                                 -0.108919      0.154289
# Tandem Walk                                   0.037235      0.030668
# Figure 8 Walk                                 0.049432      0.321008
# Jumping Sideways                              0.059896     -0.691433
# Throwing Beanbag at Target                    1.000000     -0.174223
# Tapping Test                                 -0.174223      1.000000
# Ruler Drop Test                               0.211897      0.198766
#
# ID                          Ruler Drop Test
# ID
# Balance Test                      -0.309084
# Single Leg Stance                  0.231793
# Robotrainer Front                 -0.167968
# Robotrainer Left                  -0.401425
# Robotrainer Right                 -0.381696
# Hand Grip Left                    -0.287985
# Hand Grip Right                   -0.206934
# Jump & Reach                      -0.484986
# Tandem Walk                       -0.195643
# Figure 8 Walk                      0.445800
# Jumping Sideways                  -0.291770
# Throwing Beanbag at Target         0.211897
# Tapping Test                       0.198766
# Ruler Drop Test                    1.000000

# %%
custom_cmap = LinearSegmentedColormap.from_list("custom_reds", ['#ffffff', '#c00000'])

plt.figure(figsize=(8.27, 6))

sns.heatmap(
    spearman_correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap=custom_cmap,  
    cbar=True,
    annot_kws={"size": 8}
)

plt.title("Spearman Correlation Heatmap", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig('figures/pearson_ground_truth.pdf', format='pdf')

plt.show()

# %%
spearman_correlation_matrix_robo = df_robotrainer.select_dtypes(include=[np.number]).corr(method='spearman')
print(spearman_correlation_matrix_robo)
# Out:
#                                         user      path      time  \
# user                                1.000000 -0.006080 -0.122506
# path                               -0.006080  1.000000  0.582349
# time                               -0.122506  0.582349  1.000000
# force_input_raw_y                   0.160879  0.046324 -0.045437
# force_input_raw_x                   0.089851 -0.520704 -0.954088
# ppi                                -0.053450  0.086211  0.144728
# robot_pose_z                        0.088343 -0.767961 -0.681171
# robotrainer_deviation_left          0.060006 -0.329746 -0.311098
# robot_pose_y                       -0.082486  0.556282  0.475667
# output_data_linear_z                0.001769  0.190268 -0.093646
# velocity_output_angular_z          -0.015189 -0.267293  0.117900
# output_data_linear_x                0.089856 -0.520675 -0.954287
# virtual_force_resulting_force_y    -0.045860  0.076740 -0.165423
# virtual_force_resulting_force_x     0.172472 -0.588013 -0.523795
# output_data_angular_y              -0.005259 -0.112514  0.211996
# output_data_angular_z               0.020783 -0.325497 -0.146693
# heart_rate                          0.070349 -0.027963 -0.097698
# virtual_force_position_x            0.051168 -0.753979 -0.678749
# virtual_force_position_y           -0.086646  0.723543  0.634882
# virtual_force_velocity_out_y        0.081877  0.009799 -0.249344
# virtual_force_velocity_out_x        0.133333 -0.668794 -0.964643
# force_input_scaled_limited_y        0.163396  0.031625 -0.051986
# force_input_scaled_limited_x        0.081580 -0.590618 -0.966482
# torque_input_scaled_limited_z       0.021816 -0.203714 -0.115817
# virtual_force_resulting_velocity_x  0.172547 -0.588839 -0.524555
# virtual_force_resulting_velocity_y -0.044795  0.077675 -0.166410
# virtual_force_velocity_in_y         0.197693  0.015595  0.090880
# virtual_force_velocity_in_x         0.120698 -0.617380 -0.956051
# velocity_output_linear_x            0.100050 -0.654671 -0.974795
# velocity_output_linear_y            0.068013 -0.064152 -0.204111
# torque_input_raw_z                  0.020309 -0.325411 -0.146563
# robotrainer_deviation_right        -0.114690  0.278005  0.136704
# robotrainer_deviation_front        -0.050430  0.411806  0.339625
# robot_pose_x                        0.060339 -0.619367 -0.649474
# total_duration                     -0.123886  0.582197  0.996379
# age_x                               0.039325 -0.008223 -0.038743
# age_y                               0.039325 -0.008223 -0.038743
#
#                                     force_input_raw_y  force_input_raw_x  \
# user                                         0.160879           0.089851
# path                                         0.046324          -0.520704
# time                                        -0.045437          -0.954088
# force_input_raw_y                            1.000000           0.067385
# force_input_raw_x                            0.067385           1.000000
# ppi                                          0.069190          -0.132520
# robot_pose_z                                -0.052776           0.656125
# robotrainer_deviation_left                  -0.160152           0.367727
# robot_pose_y                                 0.160244          -0.486981
# output_data_linear_z                         0.093987           0.147236
# velocity_output_angular_z                   -0.232500          -0.231836
# output_data_linear_x                         0.067648           0.999975
# virtual_force_resulting_force_y             -0.674533           0.225558
# virtual_force_resulting_force_x              0.041084           0.395805
# output_data_angular_y                       -0.111707          -0.269556
# output_data_angular_z                        0.265426           0.114338
# heart_rate                                  -0.109322           0.112980
# virtual_force_position_x                    -0.021780           0.594046
# virtual_force_position_y                     0.145972          -0.644088
# virtual_force_velocity_out_y                -0.079356           0.332396
# virtual_force_velocity_out_x                -0.144707           0.929310
# force_input_scaled_limited_y                 0.993543           0.070884
# force_input_scaled_limited_x                 0.035531           0.983859
# torque_input_scaled_limited_z                0.384811           0.097278
# virtual_force_resulting_velocity_x           0.039364           0.397242
# virtual_force_resulting_velocity_y          -0.673311           0.226690
# virtual_force_velocity_in_y                  0.928459          -0.071861
# virtual_force_velocity_in_x                 -0.150832           0.951476
# velocity_output_linear_x                     0.027426           0.957994
# velocity_output_linear_y                     0.015619           0.262618
# torque_input_raw_z                           0.263643           0.113808
# robotrainer_deviation_right                  0.207030          -0.151934
# robotrainer_deviation_front                 -0.017637          -0.306650
# robot_pose_x                                 0.072846           0.568285
# total_duration                              -0.047028          -0.956208
# age_x                                       -0.084051           0.009379
# age_y                                       -0.084051           0.009379
#
#                                          ppi  robot_pose_z  \
# user                               -0.053450      0.088343
# path                                0.086211     -0.767961
# time                                0.144728     -0.681171
# force_input_raw_y                   0.069190     -0.052776
# force_input_raw_x                  -0.132520      0.656125
# ppi                                 1.000000     -0.065588
# robot_pose_z                       -0.065588      1.000000
# robotrainer_deviation_left         -0.091012      0.432053
# robot_pose_y                        0.100682     -0.652897
# output_data_linear_z                0.056976     -0.050789
# velocity_output_angular_z           0.026317     -0.023541
# output_data_linear_x               -0.132858      0.656281
# virtual_force_resulting_force_y    -0.064722      0.188263
# virtual_force_resulting_force_x    -0.100765      0.662601
# output_data_angular_y              -0.030189     -0.032741
# output_data_angular_z              -0.031712      0.190262
# heart_rate                         -0.419079      0.046881
# virtual_force_position_x           -0.125079      0.601515
# virtual_force_position_y            0.087377     -0.714735
# virtual_force_velocity_out_y       -0.093745      0.294138
# virtual_force_velocity_out_x       -0.165235      0.711210
# force_input_scaled_limited_y        0.057267     -0.044281
# force_input_scaled_limited_x       -0.147749      0.708058
# torque_input_scaled_limited_z       0.030321      0.112647
# virtual_force_resulting_velocity_x -0.099831      0.665550
# virtual_force_resulting_velocity_y -0.064734      0.186955
# virtual_force_velocity_in_y         0.036651     -0.056849
# virtual_force_velocity_in_x        -0.161897      0.664104
# velocity_output_linear_x           -0.142646      0.747038
# velocity_output_linear_y           -0.084770      0.283678
# torque_input_raw_z                 -0.031024      0.190871
# robotrainer_deviation_right         0.061374     -0.321486
# robotrainer_deviation_front         0.001915     -0.433272
# robot_pose_x                       -0.143145      0.586432
# total_duration                      0.142843     -0.683036
# age_x                              -0.033795     -0.001147
# age_y                              -0.033795     -0.001147
#
#                                     robotrainer_deviation_left  robot_pose_y  \
# user                                                  0.060006     -0.082486
# path                                                 -0.329746      0.556282
# time                                                 -0.311098      0.475667
# force_input_raw_y                                    -0.160152      0.160244
# force_input_raw_x                                     0.367727     -0.486981
# ppi                                                  -0.091012      0.100682
# robot_pose_z                                          0.432053     -0.652897
# robotrainer_deviation_left                            1.000000     -0.768134
# robot_pose_y                                         -0.768134      1.000000
# output_data_linear_z                                 -0.038130      0.147214
# velocity_output_angular_z                            -0.184627      0.062358
# output_data_linear_x                                  0.367346     -0.486898
# virtual_force_resulting_force_y                       0.616539     -0.535946
# virtual_force_resulting_force_x                       0.124035     -0.272800
# output_data_angular_y                                -0.008926     -0.078536
# output_data_angular_z                                 0.082139     -0.089597
# heart_rate                                            0.076144     -0.071156
# virtual_force_position_x                              0.204995     -0.525496
# virtual_force_position_y                             -0.651260      0.891445
# virtual_force_velocity_out_y                          0.733555     -0.662420
# virtual_force_velocity_out_x                          0.447335     -0.628203
# force_input_scaled_limited_y                         -0.159803      0.160239
# force_input_scaled_limited_x                          0.363301     -0.515671
# torque_input_scaled_limited_z                         0.010672      0.031306
# virtual_force_resulting_velocity_x                    0.124998     -0.275631
# virtual_force_resulting_velocity_y                    0.617181     -0.535054
# virtual_force_velocity_in_y                          -0.153569      0.154056
# virtual_force_velocity_in_x                           0.445337     -0.615691
# velocity_output_linear_x                              0.373953     -0.517495
# velocity_output_linear_y                              0.658218     -0.619073
# torque_input_raw_z                                    0.083274     -0.088478
# robotrainer_deviation_right                          -0.728575      0.775464
# robotrainer_deviation_front                          -0.111031      0.359165
# robot_pose_x                                          0.064422     -0.411375
# total_duration                                       -0.310474      0.470207
# age_x                                                -0.082725      0.117921
# age_y                                                -0.082725      0.117921
#
#                                     output_data_linear_z  ...  \
# user                                            0.001769  ...
# path                                            0.190268  ...
# time                                           -0.093646  ...
# force_input_raw_y                               0.093987  ...
# force_input_raw_x                               0.147236  ...
# ppi                                             0.056976  ...
# robot_pose_z                                   -0.050789  ...
# robotrainer_deviation_left                     -0.038130  ...
# robot_pose_y                                    0.147214  ...
# output_data_linear_z                            1.000000  ...
# velocity_output_angular_z                      -0.151129  ...
# output_data_linear_x                            0.147245  ...
# virtual_force_resulting_force_y                -0.016912  ...
# virtual_force_resulting_force_x                -0.205752  ...
# output_data_angular_y                          -0.986384  ...
# output_data_angular_z                          -0.162408  ...
# heart_rate                                      0.073104  ...
# virtual_force_position_x                       -0.250973  ...
# virtual_force_position_y                        0.184765  ...
# virtual_force_velocity_out_y                   -0.063763  ...
# virtual_force_velocity_out_x                   -0.195342  ...
# force_input_scaled_limited_y                    0.088049  ...
# force_input_scaled_limited_x                    0.084742  ...
# torque_input_scaled_limited_z                   0.017464  ...
# virtual_force_resulting_velocity_x             -0.206940  ...
# virtual_force_resulting_velocity_y             -0.015654  ...
# virtual_force_velocity_in_y                    -0.017207  ...
# virtual_force_velocity_in_x                    -0.173942  ...
# velocity_output_linear_x                        0.078084  ...
# velocity_output_linear_y                       -0.090213  ...
# torque_input_raw_z                             -0.165858  ...
# robotrainer_deviation_right                     0.195962  ...
# robotrainer_deviation_front                     0.026147  ...
# robot_pose_x                                   -0.125796  ...
# total_duration                                 -0.096404  ...
# age_x                                           0.193209  ...
# age_y                                           0.193209  ...
#
#                                     virtual_force_velocity_in_x  \
# user                                                   0.120698
# path                                                  -0.617380
# time                                                  -0.956051
# force_input_raw_y                                     -0.150832
# force_input_raw_x                                      0.951476
# ppi                                                   -0.161897
# robot_pose_z                                           0.664104
# robotrainer_deviation_left                             0.445337
# robot_pose_y                                          -0.615691
# output_data_linear_z                                  -0.173942
# velocity_output_angular_z                              0.032088
# output_data_linear_x                                   0.951443
# virtual_force_resulting_force_y                        0.236882
# virtual_force_resulting_force_x                        0.456385
# output_data_angular_y                                  0.058908
# output_data_angular_z                                  0.099395
# heart_rate                                             0.138497
# virtual_force_position_x                               0.655100
# virtual_force_position_y                              -0.679513
# virtual_force_velocity_out_y                           0.311260
# virtual_force_velocity_out_x                           0.987226
# force_input_scaled_limited_y                          -0.145890
# force_input_scaled_limited_x                           0.979068
# torque_input_scaled_limited_z                         -0.033550
# virtual_force_resulting_velocity_x                     0.457799
# virtual_force_resulting_velocity_y                     0.237717
# virtual_force_velocity_in_y                           -0.116995
# virtual_force_velocity_in_x                            1.000000
# velocity_output_linear_x                               0.987187
# velocity_output_linear_y                               0.310809
# torque_input_raw_z                                     0.100930
# robotrainer_deviation_right                           -0.371772
# robotrainer_deviation_front                           -0.123958
# robot_pose_x                                           0.621995
# total_duration                                        -0.957886
# age_x                                                  0.048012
# age_y                                                  0.048012
#
#                                     velocity_output_linear_x  \
# user                                                0.100050
# path                                               -0.654671
# time                                               -0.974795
# force_input_raw_y                                   0.027426
# force_input_raw_x                                   0.957994
# ppi                                                -0.142646
# robot_pose_z                                        0.747038
# robotrainer_deviation_left                          0.373953
# robot_pose_y                                       -0.517495
# output_data_linear_z                                0.078084
# velocity_output_angular_z                          -0.131473
# output_data_linear_x                                0.958037
# virtual_force_resulting_force_y                     0.211602
# virtual_force_resulting_force_x                     0.561960
# output_data_angular_y                              -0.198512
# output_data_angular_z                               0.173640
# heart_rate                                          0.098160
# virtual_force_position_x                            0.682301
# virtual_force_position_y                           -0.695234
# virtual_force_velocity_out_y                        0.291903
# virtual_force_velocity_out_x                        0.999997
# force_input_scaled_limited_y                        0.035516
# force_input_scaled_limited_x                        0.978870
# torque_input_scaled_limited_z                       0.129193
# virtual_force_resulting_velocity_x                  0.563168
# virtual_force_resulting_velocity_y                  0.212313
# virtual_force_velocity_in_y                        -0.104350
# virtual_force_velocity_in_x                         0.987187
# velocity_output_linear_x                            1.000000
# velocity_output_linear_y                            0.233152
# torque_input_raw_z                                  0.173982
# robotrainer_deviation_right                        -0.166358
# robotrainer_deviation_front                        -0.354406
# robot_pose_x                                        0.621756
# total_duration                                     -0.977471
# age_x                                               0.029428
# age_y                                               0.029428
#
#                                     velocity_output_linear_y  \
# user                                                0.068013
# path                                               -0.064152
# time                                               -0.204111
# force_input_raw_y                                   0.015619
# force_input_raw_x                                   0.262618
# ppi                                                -0.084770
# robot_pose_z                                        0.283678
# robotrainer_deviation_left                          0.658218
# robot_pose_y                                       -0.619073
# output_data_linear_z                               -0.090213
# velocity_output_angular_z                          -0.381886
# output_data_linear_x                                0.262393
# virtual_force_resulting_force_y                     0.654050
# virtual_force_resulting_force_x                    -0.069394
# output_data_angular_y                               0.051317
# output_data_angular_z                               0.041412
# heart_rate                                          0.090547
# virtual_force_position_x                            0.069507
# virtual_force_position_y                           -0.466434
# virtual_force_velocity_out_y                        0.999991
# virtual_force_velocity_out_x                        0.291453
# force_input_scaled_limited_y                        0.008516
# force_input_scaled_limited_x                        0.244304
# torque_input_scaled_limited_z                      -0.014935
# virtual_force_resulting_velocity_x                 -0.066907
# virtual_force_resulting_velocity_y                  0.653705
# virtual_force_velocity_in_y                         0.025783
# virtual_force_velocity_in_x                         0.310809
# velocity_output_linear_x                            0.233152
# velocity_output_linear_y                            1.000000
# torque_input_raw_z                                  0.041594
# robotrainer_deviation_right                        -0.677160
# robotrainer_deviation_front                        -0.074677
# robot_pose_x                                        0.062658
# total_duration                                     -0.201638
# age_x                                              -0.103181
# age_y                                              -0.103181
#
#                                     torque_input_raw_z  \
# user                                          0.020309
# path                                         -0.325411
# time                                         -0.146563
# force_input_raw_y                             0.263643
# force_input_raw_x                             0.113808
# ppi                                          -0.031024
# robot_pose_z                                  0.190871
# robotrainer_deviation_left                    0.083274
# robot_pose_y                                 -0.088478
# output_data_linear_z                         -0.165858
# velocity_output_angular_z                     0.073189
# output_data_linear_x                          0.114101
# virtual_force_resulting_force_y              -0.235662
# virtual_force_resulting_force_x               0.158606
# output_data_angular_y                         0.105728
# output_data_angular_z                         0.999298
# heart_rate                                   -0.068869
# virtual_force_position_x                      0.351830
# virtual_force_position_y                     -0.269913
# virtual_force_velocity_out_y                  0.037644
# virtual_force_velocity_out_x                  0.131885
# force_input_scaled_limited_y                  0.276484
# force_input_scaled_limited_x                  0.143280
# torque_input_scaled_limited_z                 0.846894
# virtual_force_resulting_velocity_x            0.158277
# virtual_force_resulting_velocity_y           -0.235126
# virtual_force_velocity_in_y                   0.371069
# virtual_force_velocity_in_x                   0.100930
# velocity_output_linear_x                      0.173982
# velocity_output_linear_y                      0.041594
# torque_input_raw_z                            1.000000
# robotrainer_deviation_right                  -0.022713
# robotrainer_deviation_front                  -0.194408
# robot_pose_x                                  0.298666
# total_duration                               -0.141785
# age_x                                        -0.066744
# age_y                                        -0.066744
#
#                                     robotrainer_deviation_right  \
# user                                                  -0.114690
# path                                                   0.278005
# time                                                   0.136704
# force_input_raw_y                                      0.207030
# force_input_raw_x                                     -0.151934
# ppi                                                    0.061374
# robot_pose_z                                          -0.321486
# robotrainer_deviation_left                            -0.728575
# robot_pose_y                                           0.775464
# output_data_linear_z                                   0.195962
# velocity_output_angular_z                             -0.023226
# output_data_linear_x                                  -0.151814
# virtual_force_resulting_force_y                       -0.619918
# virtual_force_resulting_force_x                       -0.057118
# output_data_angular_y                                 -0.172353
# output_data_angular_z                                 -0.021686
# heart_rate                                            -0.079306
# virtual_force_position_x                              -0.220771
# virtual_force_position_y                               0.669806
# virtual_force_velocity_out_y                          -0.740424
# virtual_force_velocity_out_x                          -0.371182
# force_input_scaled_limited_y                           0.214314
# force_input_scaled_limited_x                          -0.162401
# torque_input_scaled_limited_z                          0.072368
# virtual_force_resulting_velocity_x                    -0.059834
# virtual_force_resulting_velocity_y                    -0.619364
# virtual_force_velocity_in_y                            0.162955
# virtual_force_velocity_in_x                           -0.371772
# velocity_output_linear_x                              -0.166358
# velocity_output_linear_y                              -0.677160
# torque_input_raw_z                                    -0.022713
# robotrainer_deviation_right                            1.000000
# robotrainer_deviation_front                            0.245337
# robot_pose_x                                          -0.083041
# total_duration                                         0.138742
# age_x                                                  0.145145
# age_y                                                  0.145145
#
#                                     robotrainer_deviation_front  robot_pose_x  \
# user                                                  -0.050430      0.060339
# path                                                   0.411806     -0.619367
# time                                                   0.339625     -0.649474
# force_input_raw_y                                     -0.017637      0.072846
# force_input_raw_x                                     -0.306650      0.568285
# ppi                                                    0.001915     -0.143145
# robot_pose_z                                          -0.433272      0.586432
# robotrainer_deviation_left                            -0.111031      0.064422
# robot_pose_y                                           0.359165     -0.411375
# output_data_linear_z                                   0.026147     -0.125796
# velocity_output_angular_z                              0.054305      0.154190
# output_data_linear_x                                  -0.306704      0.568154
# virtual_force_resulting_force_y                       -0.083757     -0.094642
# virtual_force_resulting_force_x                       -0.108335      0.484438
# output_data_angular_y                                  0.013722      0.033715
# output_data_angular_z                                 -0.195150      0.302181
# heart_rate                                            -0.008538      0.096768
# virtual_force_position_x                              -0.362293      0.939448
# virtual_force_position_y                               0.357851     -0.596753
# virtual_force_velocity_out_y                          -0.074814      0.059327
# virtual_force_velocity_out_x                          -0.145744      0.649785
# force_input_scaled_limited_y                          -0.020065      0.078405
# force_input_scaled_limited_x                          -0.368583      0.615764
# torque_input_scaled_limited_z                         -0.158816      0.228645
# virtual_force_resulting_velocity_x                    -0.111253      0.486032
# virtual_force_resulting_velocity_y                    -0.081573     -0.095165
# virtual_force_velocity_in_y                            0.101593      0.085506
# virtual_force_velocity_in_x                           -0.123958      0.621995
# velocity_output_linear_x                              -0.354406      0.621756
# velocity_output_linear_y                              -0.074677      0.062658
# torque_input_raw_z                                    -0.194408      0.298666
# robotrainer_deviation_right                            0.245337     -0.083041
# robotrainer_deviation_front                            1.000000     -0.422970
# robot_pose_x                                          -0.422970      1.000000
# total_duration                                         0.341104     -0.629226
# age_x                                                  0.076201     -0.043262
# age_y                                                  0.076201     -0.043262
#
#                                     total_duration     age_x     age_y
# user                                     -0.123886  0.039325  0.039325
# path                                      0.582197 -0.008223 -0.008223
# time                                      0.996379 -0.038743 -0.038743
# force_input_raw_y                        -0.047028 -0.084051 -0.084051
# force_input_raw_x                        -0.956208  0.009379  0.009379
# ppi                                       0.142843 -0.033795 -0.033795
# robot_pose_z                             -0.683036 -0.001147 -0.001147
# robotrainer_deviation_left               -0.310474 -0.082725 -0.082725
# robot_pose_y                              0.470207  0.117921  0.117921
# output_data_linear_z                     -0.096404  0.193209  0.193209
# velocity_output_angular_z                 0.125095  0.025657  0.025657
# output_data_linear_x                     -0.956396  0.009920  0.009920
# virtual_force_resulting_force_y          -0.169540  0.022391  0.022391
# virtual_force_resulting_force_x          -0.527243  0.092373  0.092373
# output_data_angular_y                     0.215093 -0.193379 -0.193379
# output_data_angular_z                    -0.141717 -0.064046 -0.064046
# heart_rate                               -0.096511 -0.080440 -0.080440
# virtual_force_position_x                 -0.652702 -0.003082 -0.003082
# virtual_force_position_y                  0.620971  0.086941  0.086941
# virtual_force_velocity_out_y             -0.244797 -0.114298 -0.114298
# virtual_force_velocity_out_x             -0.967790  0.043032  0.043032
# force_input_scaled_limited_y             -0.053613 -0.085746 -0.085746
# force_input_scaled_limited_x             -0.967968  0.025283  0.025283
# torque_input_scaled_limited_z            -0.113346 -0.077626 -0.077626
# virtual_force_resulting_velocity_x       -0.528001  0.091357  0.091357
# virtual_force_resulting_velocity_y       -0.170635  0.022061  0.022061
# virtual_force_velocity_in_y               0.094893 -0.136416 -0.136416
# virtual_force_velocity_in_x              -0.957886  0.048012  0.048012
# velocity_output_linear_x                 -0.977471  0.029428  0.029428
# velocity_output_linear_y                 -0.201638 -0.103181 -0.103181
# torque_input_raw_z                       -0.141785 -0.066744 -0.066744
# robotrainer_deviation_right               0.138742  0.145145  0.145145
# robotrainer_deviation_front               0.341104  0.076201  0.076201
# robot_pose_x                             -0.629226 -0.043262 -0.043262
# total_duration                            1.000000 -0.040158 -0.040158
# age_x                                    -0.040158  1.000000  1.000000
# age_y                                    -0.040158  1.000000  1.000000
#
# [37 rows x 37 columns]

# %%
custom_cmap = LinearSegmentedColormap.from_list("custom_reds", ['#ffffff', '#c00000'])

rows, cols = correlation_matrix_robo.shape

fig_width = max(6, cols * 0.6)
fig_height = max(4, rows * 0.6)

plt.figure(figsize=(fig_width, fig_height))

sns.heatmap(
    spearman_correlation_matrix_robo,
    annot=True,
    fmt=".2f",
    cmap=custom_cmap,  
    cbar=True,
    annot_kws={"size": 8}
)

plt.title("Spearman Correlation Heatmap", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.tight_layout() 

plt.savefig('figures/pearson_ground_truth.pdf', format='pdf')

plt.show()

# %% [markdown]
# ##  Principal Component Analysis (PCA)
# Dimensionality reduction technique used to simplify datasets while preserving as much variance as possible. PCA transforms the data into a new coordinate system where the axes (principal components) are ordered by the amount of variance they capture.

# %%
# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_df)

# Apply PCA
pca = PCA(n_components=13)  # Adjust the number of components as needed
pca_result = pca.fit_transform(scaled_data)

# Create a DataFrame for the PCA results
pca_df = pd.DataFrame(
    pca_result,
    columns=[f"PC{i+1}" for i in range(pca.n_components_)],
    index=numeric_df.index
)

print(pca_df)
# Out:
#          PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 1  -2.314457  0.408180  1.023618  1.858403  1.556847  1.317234  0.411083
# 2   0.063024 -1.551429  0.167915 -1.419555  1.105528 -0.718162  0.546925
# 3   2.236879 -0.661092 -0.341761  1.369300 -1.355919 -0.340149 -0.304733
# 4   3.332162  0.751447 -0.805764 -1.294721 -0.763969  1.338869  0.117974
# 5  -0.409405 -0.203623 -1.869309  2.806640 -0.492912 -1.932576  0.072955
# 6  -2.787913 -0.021296 -0.733535 -0.821689 -1.155270 -0.258550  0.026706
# 7  -1.880892  1.704929 -1.859665  0.009902  0.244533  0.432778  0.032649
# 8   0.970026 -1.624765  0.639424 -1.402474  0.717044  0.393658 -0.419833
# 9   2.743244 -0.640946 -0.312043  2.240135  0.193098  0.975661  0.788242
# 10  1.399056  1.559334 -0.144099 -0.198479 -0.704134  0.628018  0.142446
# 11 -2.280434 -0.874128 -0.461558  0.209347  0.109129  1.568311  1.400036
# 12 -3.406336  1.447531 -1.588029 -0.900942 -0.673775 -0.489423 -0.344280
# 13 -0.800350 -0.659026  2.177662  0.416705  0.855723  0.729474 -0.760763
# 14 -2.531131  1.764581 -0.821466 -0.812902 -0.871538  0.546730  0.358185
# 15  0.853194  1.185634  0.663153 -0.993215  0.253404 -0.590448 -0.882703
# 16  0.124069 -2.389254  0.232889  0.242768  0.085593 -1.342184  1.707543
# 17  1.869990 -2.127200 -4.036320 -0.847661  2.404064  0.399883 -0.906616
# 18 -3.247971 -1.412344  0.411101  1.243066 -0.300590  0.345554 -0.375508
# 19  2.618979 -0.270245  0.508242  1.181480  0.437684  0.128033 -1.169688
# 20 -0.424021  1.145151 -0.498998  0.319949 -0.787726 -0.002549 -0.484751
# 21 -2.409429  0.880708  1.295337  0.733484  0.403808 -0.329601 -1.473103
# 22 -2.619221 -4.741073  1.162874 -1.393923 -0.310621 -0.836777 -0.136442
# 23  0.391641  0.137634  0.948838 -1.013492 -1.164895  1.012299  0.508758
# 24  1.521646  2.472421 -0.097086 -0.138632  0.848720 -1.183257  0.859394
# 25  3.748609 -0.875263  1.019090 -0.419093 -0.250347 -0.468168  0.437553
# 26 -0.210001  4.115423  1.775795 -0.672397  1.990360 -0.991496  0.606728
# 27  1.887626  0.812539 -0.091856 -0.604246 -1.378731 -0.523885 -0.405676
# 28  1.561413 -0.333829  1.635550  0.302242 -0.995109  0.190723 -0.353082
#
#          PC8       PC9      PC10      PC11      PC12      PC13
# 1   1.304574  0.856435  0.592370 -0.413596 -0.196003 -0.054089
# 2   0.844909 -0.505737  0.155746 -0.333909 -0.073156 -0.278443
# 3  -0.088971  0.349162 -0.593823 -0.885455  0.247350  0.044869
# 4   0.644303 -0.375757 -0.203291 -0.096189 -0.015368 -0.144510
# 5   0.751238  0.607523 -0.103822  0.814048  0.088687  0.054578
# 6  -0.613435 -0.617348  0.970109 -0.325989 -0.047590  0.077501
# 7  -1.036366 -1.594744 -0.634544  0.002599 -0.136535  0.183657
# 8   1.492411 -0.605076 -0.710330  0.504827  0.237871  0.246072
# 9  -0.111808 -0.852966 -0.460470 -0.142158 -0.223339 -0.193082
# 10 -0.080100  0.055935  0.332938  0.060610 -0.649331 -0.035184
# 11  0.026210 -0.012715  0.564781  0.496394  0.142237  0.283713
# 12  0.628599  0.057091 -0.929262  0.242407  0.214697 -0.049065
# 13 -0.611606 -0.088803 -0.434907  0.379619  0.018719  0.530470
# 14  0.002279  0.546727 -0.217062 -0.053614  0.059207 -0.028424
# 15  1.171802  0.113750 -0.162327 -0.365254 -0.576645  0.217247
# 16 -0.447136 -0.259086  0.035096  0.005520 -0.661607  0.105351
# 17 -0.921776  1.130556  0.278826 -0.140749  0.039257  0.073953
# 18  0.139621 -0.357826  0.162278 -0.643893  0.872388 -0.032170
# 19 -0.214711 -0.788753  0.836563  0.510384  0.125394 -0.435646
# 20  0.130155  0.446845 -0.000825 -0.063644 -0.414661 -0.289990
# 21 -0.571264 -0.403651 -0.226667  0.106861 -0.361595 -0.316773
# 22 -0.335363  0.207941 -0.013625 -0.010396 -0.150563 -0.245042
# 23 -0.526538  1.151901 -0.311926  0.501492  0.211666 -0.537106
# 24  0.094295 -0.026129 -0.514881 -0.171243  0.337260  0.097422
# 25 -0.425856 -0.173605 -0.257473  0.011305  0.563536 -0.080151
# 26 -0.805614  0.362808  0.404976 -0.027478  0.312715 -0.106260
# 27  0.389181 -0.212430  1.896472  0.130156  0.223084  0.366051
# 28 -0.829033  0.987955 -0.454921 -0.092654 -0.187672  0.545053

# %%
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA Scatterplot')
plt.show()

# %%
loadings = pd.DataFrame(
    pca.components_,
    columns=numeric_df.columns,
    index=[f"PC{i+1}" for i in range(pca.n_components_)]
)
print(loadings)
# Out:
# ID    Balance Test  Single Leg Stance  Robotrainer Front  Robotrainer Left  \
# PC1       0.124504          -0.040268           0.315576          0.388877
# PC2       0.457027          -0.450791          -0.179802         -0.110802
# PC3       0.111059          -0.009055           0.342081          0.161018
# PC4      -0.094111          -0.242523           0.185744          0.038034
# PC5       0.278089           0.014954           0.247704          0.059615
# PC6      -0.242721          -0.467888          -0.141279         -0.223616
# PC7       0.397564           0.483411           0.149190         -0.333713
# PC8      -0.089683          -0.144909          -0.106936          0.312179
# PC9      -0.023673           0.032500           0.373759         -0.174583
# PC10      0.424180           0.174093          -0.325461          0.456893
# PC11     -0.086867          -0.181222           0.577447          0.193630
# PC12      0.457700          -0.432777           0.032155          0.034092
# PC13      0.221312          -0.099544           0.118363         -0.513611
#
# ID    Robotrainer Right  Hand Grip Left  Hand Grip Right  Jump & Reach  \
# PC1            0.404540        0.405400         0.406181      0.276717
# PC2           -0.114057       -0.106417        -0.134989      0.200679
# PC3            0.208575        0.076707        -0.017822     -0.311426
# PC4            0.213692       -0.019717        -0.092054     -0.262066
# PC5            0.042696       -0.166057        -0.234664      0.346704
# PC6           -0.044614        0.344775         0.339993      0.254424
# PC7           -0.233117        0.317766         0.018356      0.188993
# PC8            0.185455       -0.248486        -0.302347      0.185281
# PC9            0.035336       -0.057251        -0.043915     -0.403413
# PC10           0.070945       -0.156593         0.187805     -0.069916
# PC11          -0.448458       -0.193854        -0.070777      0.308744
# PC12          -0.219679        0.259790        -0.051352     -0.409317
# PC13           0.593553       -0.274057         0.007147      0.146804
#
# ID    Tandem Walk  Figure 8 Walk  Jumping Sideways  \
# PC1     -0.039294      -0.246519          0.072913
# PC2     -0.082988      -0.239853          0.496676
# PC3     -0.338626       0.091299         -0.018174
# PC4      0.710619       0.290578          0.012466
# PC5     -0.029214       0.199041         -0.280851
# PC6     -0.097056       0.521372          0.068937
# PC7      0.041125       0.349946         -0.026586
# PC8     -0.396106       0.412632         -0.168703
# PC9     -0.300478       0.237580          0.535356
# PC10     0.228526       0.352634          0.285383
# PC11     0.194422      -0.009761          0.122580
# PC12    -0.044892      -0.025176         -0.449079
# PC13     0.096546      -0.042821         -0.087815
#
# ID    Throwing Beanbag at Target  Tapping Test  Ruler Drop Test
# PC1                    -0.164490      0.051874        -0.255199
# PC2                     0.198546     -0.235327        -0.233618
# PC3                     0.492129     -0.449952         0.360508
# PC4                     0.132012     -0.199555        -0.355462
# PC5                     0.481800      0.532497        -0.133530
# PC6                     0.133484      0.090790         0.197368
# PC7                    -0.115403     -0.334331        -0.182499
# PC8                    -0.362745     -0.284559        -0.268334
# PC9                    -0.198254      0.389536        -0.186094
# PC10                   -0.082507      0.140638         0.347517
# PC11                   -0.248621     -0.104311         0.352184
# PC12                   -0.295695      0.145864         0.045361
# PC13                   -0.280295     -0.021682         0.341160

# %% [markdown]
# ## Scatterplot

# %%
num_cols = 3
combs = list(combinations(numeric_df.columns, 2))
num_rows = (len(combs) + num_cols - 1) // num_cols  

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
axes = axes.flatten()

colors = sns.color_palette("husl", 8)

for idx, (x_col, y_col) in enumerate(combs):
    sns.scatterplot(
        data=numeric_df,
        x=x_col,
        y=y_col,
        color=colors[0],
        ax=axes[idx]
    )
    axes[idx].set_title(f"{x_col} vs. {y_col}", fontsize=10)
    axes[idx].set_xlabel(x_col, fontsize=8)
    axes[idx].set_ylabel(y_col, fontsize=8)
    axes[idx].tick_params(axis='both', labelsize=6)

for ax in axes[len(combs):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation between Ground Truth and RoboTrainer

# %%
numeric_df = numeric_df.reset_index()
df_robotrainer["user"] = df_robotrainer["user"].astype(str)
numeric_df["index"] = numeric_df["index"].astype(str)
print(numeric_df.columns)
# Out:
# Index(['index', 'Balance Test', 'Single Leg Stance', 'Robotrainer Front',
#        'Robotrainer Left', 'Robotrainer Right', 'Hand Grip Left',
#        'Hand Grip Right', 'Jump & Reach', 'Tandem Walk', 'Figure 8 Walk',
#        'Jumping Sideways', 'Throwing Beanbag at Target', 'Tapping Test',
#        'Ruler Drop Test'],
#       dtype='object', name='ID')

# %%
df_merged = df_robotrainer.merge(numeric_df, left_on="user", right_on="index", how="inner")
df_merged = df_merged.drop(columns=['index'])
print(df_merged)
# Out:
#     user  path  time  force_input_raw_y  force_input_raw_x          ppi  \
# 0      2     8   0.0         -10.077319          93.212254          NaN
# 1      5     1   4.5           4.212586          46.885345          NaN
# 2      5     2   4.0           5.931689          52.868197  1407.500000
# 3      5     3   3.5          11.262652          59.007991  1097.333333
# 4      5     4   2.5          -1.157651          62.080021  2359.000000
# ..   ...   ...   ...                ...                ...          ...
# 463   28    16   6.0           7.879871          30.172225   906.679630
# 464   28    17   6.5          14.185067          31.171210   614.581481
# 465   28    18   6.0          -0.209474          36.628060   545.625000
# 466   28    19   6.0          -3.443169          46.423700   745.547863
# 467   28    20   6.5          -4.032119          42.308031   719.925926
#
#      robot_pose_z  robotrainer_deviation_left  robot_pose_y  \
# 0        2.843109                    0.481815      8.945766
# 1        2.898135                    0.419149     10.093447
# 2        1.859722                    0.350801     10.167159
# 3        2.005619                    0.320000     10.132463
# 4        2.845270                    0.281152     10.007904
# ..            ...                         ...           ...
# 463     -0.011168                    0.178631     10.540269
# 464     -0.103635                    0.214837     10.538270
# 465      0.512371                    0.328544     10.253969
# 466      0.521944                    0.374754     10.134815
# 467      0.408480                    0.363099     10.230154
#
#      output_data_linear_z  ...  Robotrainer Right  Hand Grip Left  \
# 0               87.194709  ...             180.53            39.4
# 1              298.302037  ...             172.04            27.3
# 2              167.436324  ...             172.04            27.3
# 3              130.575519  ...             172.04            27.3
# 4              160.839418  ...             172.04            27.3
# ..                    ...  ...                ...             ...
# 463            269.449807  ...             250.92            49.7
# 464            322.455806  ...             250.92            49.7
# 465            349.764596  ...             250.92            49.7
# 466            367.793604  ...             250.92            49.7
# 467            359.647919  ...             250.92            49.7
#
#      Hand Grip Right  Jump & Reach  Tandem Walk  Figure 8 Walk  \
# 0               41.2          48.0         7.80           4.97
# 1               33.1          36.0        16.09           4.86
# 2               33.1          36.0        16.09           4.86
# 3               33.1          36.0        16.09           4.86
# 4               33.1          36.0        16.09           4.86
# ..               ...           ...          ...            ...
# 463             55.2          35.0         9.44           4.40
# 464             55.2          35.0         9.44           4.40
# 465             55.2          35.0         9.44           4.40
# 466             55.2          35.0         9.44           4.40
# 467             55.2          35.0         9.44           4.40
#
#      Jumping Sideways  Throwing Beanbag at Target  Tapping Test  \
# 0                37.0                   15.500000         17.14
# 1                49.0                    8.500000         10.16
# 2                49.0                    8.500000         10.16
# 3                49.0                    8.500000         10.16
# 4                49.0                    8.500000         10.16
# ..                ...                         ...           ...
# 463              54.0                   16.666667          7.86
# 464              54.0                   16.666667          7.86
# 465              54.0                   16.666667          7.86
# 466              54.0                   16.666667          7.86
# 467              54.0                   16.666667          7.86
#
#      Ruler Drop Test
# 0               14.0
# 1                3.5
# 2                3.5
# 3                3.5
# 4                3.5
# ..               ...
# 463             15.0
# 464             15.0
# 465             15.0
# 466             15.0
# 467             15.0
#
# [468 rows x 52 columns]

# %%
num_df = df_merged.select_dtypes(include=['number'])
gt_cols = numeric_df.columns.drop('index')

# %% [markdown]
# ### Pearson

# %%
corr_matrix = num_df.corr().loc[:, gt_cols]
print("Korrelationsmatrix:")
print(corr_matrix)
# Out:
# Korrelationsmatrix:
# ID                                  Balance Test  Single Leg Stance  \
# path                                   -0.003351           0.000142
# time                                   -0.048059           0.035348
# force_input_raw_y                       0.240490          -0.082010
# force_input_raw_x                       0.116833          -0.062583
# ppi                                     0.021777           0.079427
# robot_pose_z                            0.035635          -0.001432
# robotrainer_deviation_left              0.091071          -0.172007
# robot_pose_y                           -0.118918           0.091906
# output_data_linear_z                   -0.190562           0.195889
# velocity_output_angular_z              -0.029933           0.050965
# output_data_linear_x                    0.116905          -0.062329
# virtual_force_resulting_force_y        -0.046251          -0.007227
# virtual_force_resulting_force_x         0.036811          -0.014163
# output_data_angular_y                   0.164805          -0.181899
# output_data_angular_z                   0.061360           0.001394
# heart_rate                             -0.029380          -0.021714
# virtual_force_position_x                0.089237           0.196327
# virtual_force_position_y               -0.146794           0.044761
# virtual_force_velocity_out_y            0.201869          -0.095113
# virtual_force_velocity_out_x            0.150019          -0.004238
# force_input_scaled_limited_y            0.248530          -0.098401
# force_input_scaled_limited_x            0.125821          -0.052996
# torque_input_scaled_limited_z           0.054857          -0.021092
# virtual_force_resulting_velocity_x      0.037044          -0.013078
# virtual_force_resulting_velocity_y     -0.046500          -0.006936
# virtual_force_velocity_in_y             0.256898          -0.094153
# virtual_force_velocity_in_x             0.157206          -0.003495
# velocity_output_linear_x                0.104399          -0.012988
# velocity_output_linear_y                0.197163          -0.091028
# torque_input_raw_z                      0.061831           0.001830
# robotrainer_deviation_right            -0.164089           0.238063
# robotrainer_deviation_front            -0.033655           0.144606
# robot_pose_x                            0.121829           0.079936
# total_duration                         -0.047994           0.035747
# age_x                                  -0.397362           0.593531
# age_y                                  -0.397362           0.593531
# Balance Test                            1.000000          -0.442672
# Single Leg Stance                      -0.442672           1.000000
# Robotrainer Front                       0.060091           0.188538
# Robotrainer Left                        0.141512           0.020057
# Robotrainer Right                       0.101352          -0.003826
# Hand Grip Left                          0.100830           0.073906
# Hand Grip Right                        -0.012873           0.105628
# Jump & Reach                            0.474169          -0.323765
# Tandem Walk                            -0.209543           0.014955
# Figure 8 Walk                          -0.586732           0.330744
# Jumping Sideways                        0.657172          -0.620668
# Throwing Beanbag at Target              0.323320          -0.361669
# Tapping Test                           -0.262258           0.269363
# Ruler Drop Test                        -0.444971           0.357447
#
# ID                                  Robotrainer Front  Robotrainer Left  \
# path                                         0.021275          0.017964
# time                                        -0.137165         -0.065853
# force_input_raw_y                            0.008814          0.155692
# force_input_raw_x                            0.282776          0.229008
# ppi                                          0.089826         -0.026279
# robot_pose_z                                 0.017302          0.026194
# robotrainer_deviation_left                  -0.021311          0.038315
# robot_pose_y                                -0.022353         -0.107278
# output_data_linear_z                         0.248704          0.210010
# velocity_output_angular_z                    0.054102         -0.037101
# output_data_linear_x                         0.282997          0.229075
# virtual_force_resulting_force_y             -0.000631         -0.024253
# virtual_force_resulting_force_x              0.198608          0.090649
# output_data_angular_y                       -0.281825         -0.241865
# output_data_angular_z                       -0.070612         -0.012506
# heart_rate                                   0.071985          0.048550
# virtual_force_position_x                     0.128366          0.122985
# virtual_force_position_y                    -0.045558         -0.125144
# virtual_force_velocity_out_y                -0.005101          0.130060
# virtual_force_velocity_out_x                 0.290099          0.227307
# force_input_scaled_limited_y                 0.003058          0.168589
# force_input_scaled_limited_x                 0.213174          0.173668
# torque_input_scaled_limited_z               -0.054863          0.015955
# virtual_force_resulting_velocity_x           0.197992          0.089615
# virtual_force_resulting_velocity_y           0.000070         -0.023750
# virtual_force_velocity_in_y                 -0.028530          0.133538
# virtual_force_velocity_in_x                  0.284766          0.233076
# velocity_output_linear_x                     0.215929          0.153074
# velocity_output_linear_y                    -0.000364          0.147938
# torque_input_raw_z                          -0.071905         -0.015135
# robotrainer_deviation_right                  0.060187         -0.078737
# robotrainer_deviation_front                  0.087263         -0.049113
# robot_pose_x                                 0.105068          0.097230
# total_duration                              -0.137223         -0.065128
# age_x                                        0.089096         -0.076335
# age_y                                        0.089096         -0.076335
# Balance Test                                 0.060091          0.141512
# Single Leg Stance                            0.188538          0.020057
# Robotrainer Front                            1.000000          0.641486
# Robotrainer Left                             0.641486          1.000000
# Robotrainer Right                            0.766309          0.876422
# Hand Grip Left                               0.671599          0.546169
# Hand Grip Right                              0.542791          0.637915
# Jump & Reach                                 0.106219          0.261807
# Tandem Walk                                 -0.106989         -0.047990
# Figure 8 Walk                               -0.134720         -0.366412
# Jumping Sideways                            -0.174730         -0.041196
# Throwing Beanbag at Target                   0.043711         -0.177747
# Tapping Test                                 0.035875          0.053993
# Ruler Drop Test                             -0.209271         -0.251914
#
# ID                                  Robotrainer Right  Hand Grip Left  \
# path                                         0.024247        0.022792
# time                                        -0.093990       -0.068935
# force_input_raw_y                            0.070327        0.011189
# force_input_raw_x                            0.299960        0.323081
# ppi                                         -0.001047       -0.097116
# robot_pose_z                                 0.008382        0.007397
# robotrainer_deviation_left                  -0.016808        0.023919
# robot_pose_y                                -0.056858       -0.060743
# output_data_linear_z                         0.237359        0.256199
# velocity_output_angular_z                   -0.002295        0.033939
# output_data_linear_x                         0.300071        0.323333
# virtual_force_resulting_force_y             -0.014745       -0.005659
# virtual_force_resulting_force_x              0.103874        0.209191
# output_data_angular_y                       -0.275463       -0.295279
# output_data_angular_z                       -0.052920       -0.067744
# heart_rate                                   0.169118        0.217024
# virtual_force_position_x                     0.134967        0.161574
# virtual_force_position_y                    -0.080355       -0.077919
# virtual_force_velocity_out_y                 0.058500        0.015199
# virtual_force_velocity_out_x                 0.285965        0.273991
# force_input_scaled_limited_y                 0.075487        0.007991
# force_input_scaled_limited_x                 0.216929        0.210008
# torque_input_scaled_limited_z               -0.022558       -0.063703
# virtual_force_resulting_velocity_x           0.103033        0.209333
# virtual_force_resulting_velocity_y          -0.014338       -0.005209
# virtual_force_velocity_in_y                  0.053976        0.004012
# virtual_force_velocity_in_x                  0.296392        0.266224
# velocity_output_linear_x                     0.196662        0.192163
# velocity_output_linear_y                     0.066206        0.031569
# torque_input_raw_z                          -0.056149       -0.068971
# robotrainer_deviation_right                 -0.014503       -0.003807
# robotrainer_deviation_front                 -0.014859        0.026327
# robot_pose_x                                 0.118739        0.141947
# total_duration                              -0.092890       -0.068460
# age_x                                       -0.144802        0.007797
# age_y                                       -0.144802        0.007797
# Balance Test                                 0.101352        0.100830
# Single Leg Stance                           -0.003826        0.073906
# Robotrainer Front                            0.766309        0.671599
# Robotrainer Left                             0.876422        0.546169
# Robotrainer Right                            1.000000        0.670293
# Hand Grip Left                               0.670293        1.000000
# Hand Grip Right                              0.711045        0.895836
# Jump & Reach                                 0.272528        0.379142
# Tandem Walk                                 -0.038097       -0.084345
# Figure 8 Walk                               -0.324500       -0.150366
# Jumping Sideways                            -0.050112       -0.013098
# Throwing Beanbag at Target                  -0.096660       -0.174773
# Tapping Test                                 0.026018        0.041955
# Ruler Drop Test                             -0.303290       -0.201732
#
# ID                                  Hand Grip Right  Jump & Reach  \
# path                                       0.020806      0.010206
# time                                      -0.035031     -0.017635
# force_input_raw_y                         -0.002009      0.128016
# force_input_raw_x                          0.240134      0.161658
# ppi                                       -0.106266      0.002932
# robot_pose_z                              -0.000427      0.017597
# robotrainer_deviation_left                -0.013030      0.077498
# robot_pose_y                              -0.044888     -0.099441
# output_data_linear_z                       0.276136     -0.017556
# velocity_output_angular_z                  0.018611     -0.031224
# output_data_linear_x                       0.240370      0.161327
# virtual_force_resulting_force_y           -0.014941     -0.015627
# virtual_force_resulting_force_x            0.127709      0.032474
# output_data_angular_y                     -0.303483     -0.008147
# output_data_angular_z                     -0.069232      0.018974
# heart_rate                                 0.226316     -0.036888
# virtual_force_position_x                   0.128196      0.096150
# virtual_force_position_y                  -0.061821     -0.119212
# virtual_force_velocity_out_y              -0.008874      0.133208
# virtual_force_velocity_out_x               0.204148      0.116389
# force_input_scaled_limited_y               0.001798      0.128442
# force_input_scaled_limited_x               0.157333      0.099949
# torque_input_scaled_limited_z             -0.055461      0.039521
# virtual_force_resulting_velocity_x         0.127792      0.033148
# virtual_force_resulting_velocity_y        -0.014728     -0.016057
# virtual_force_velocity_in_y               -0.005703      0.150734
# virtual_force_velocity_in_x                0.203936      0.122273
# velocity_output_linear_x                   0.136710      0.068604
# velocity_output_linear_y                   0.010200      0.138840
# torque_input_raw_z                        -0.071350      0.017809
# robotrainer_deviation_right               -0.032082     -0.109269
# robotrainer_deviation_front               -0.058714     -0.034808
# robot_pose_x                               0.099014      0.115818
# total_duration                            -0.034560     -0.015847
# age_x                                      0.039015     -0.445137
# age_y                                      0.039015     -0.445137
# Balance Test                              -0.012873      0.474169
# Single Leg Stance                          0.105628     -0.323765
# Robotrainer Front                          0.542791      0.106219
# Robotrainer Left                           0.637915      0.261807
# Robotrainer Right                          0.711045      0.272528
# Hand Grip Left                             0.895836      0.379142
# Hand Grip Right                            1.000000      0.370621
# Jump & Reach                               0.370621      1.000000
# Tandem Walk                               -0.036754     -0.041553
# Figure 8 Walk                             -0.178728     -0.461849
# Jumping Sideways                           0.008247      0.269363
# Throwing Beanbag at Target                -0.325467     -0.135443
# Tapping Test                               0.205227      0.303014
# Ruler Drop Test                           -0.136038     -0.610479
#
# ID                                  Tandem Walk  Figure 8 Walk  \
# path                                   0.003110       0.009026
# time                                  -0.019865       0.078442
# force_input_raw_y                     -0.069060      -0.178300
# force_input_raw_x                      0.115243      -0.085991
# ppi                                    0.289409       0.130387
# robot_pose_z                          -0.030167      -0.061238
# robotrainer_deviation_left            -0.081353      -0.053184
# robot_pose_y                           0.101744       0.152669
# output_data_linear_z                  -0.000247       0.166588
# velocity_output_angular_z             -0.005759       0.017950
# output_data_linear_x                   0.115237      -0.085831
# virtual_force_resulting_force_y        0.004020       0.048163
# virtual_force_resulting_force_x       -0.023938      -0.037936
# output_data_angular_y                 -0.015131      -0.149253
# output_data_angular_z                 -0.016718      -0.020807
# heart_rate                            -0.218075      -0.125453
# virtual_force_position_x               0.015205      -0.080824
# virtual_force_position_y               0.089819       0.183881
# virtual_force_velocity_out_y          -0.080118      -0.149418
# virtual_force_velocity_out_x           0.096399      -0.126581
# force_input_scaled_limited_y          -0.068924      -0.187851
# force_input_scaled_limited_x           0.053941      -0.118752
# torque_input_scaled_limited_z         -0.044104      -0.033965
# virtual_force_resulting_velocity_x    -0.024931      -0.038388
# virtual_force_resulting_velocity_y     0.003888       0.048131
# virtual_force_velocity_in_y           -0.080830      -0.210524
# virtual_force_velocity_in_x            0.111512      -0.132248
# velocity_output_linear_x               0.066829      -0.106650
# velocity_output_linear_y              -0.076951      -0.154090
# torque_input_raw_z                    -0.016674      -0.019519
# robotrainer_deviation_right            0.139451       0.198290
# robotrainer_deviation_front            0.081892       0.065331
# robot_pose_x                           0.004409      -0.105728
# total_duration                        -0.021429       0.077518
# age_x                                  0.086046       0.672675
# age_y                                  0.086046       0.672675
# Balance Test                          -0.209543      -0.586732
# Single Leg Stance                      0.014955       0.330744
# Robotrainer Front                     -0.106989      -0.134720
# Robotrainer Left                      -0.047990      -0.366412
# Robotrainer Right                     -0.038097      -0.324500
# Hand Grip Left                        -0.084345      -0.150366
# Hand Grip Right                       -0.036754      -0.178728
# Jump & Reach                          -0.041553      -0.461849
# Tandem Walk                            1.000000       0.259313
# Figure 8 Walk                          0.259313       1.000000
# Jumping Sideways                      -0.177755      -0.524510
# Throwing Beanbag at Target            -0.204962      -0.076518
# Tapping Test                           0.145594       0.061027
# Ruler Drop Test                       -0.345596       0.470184
#
# ID                                  Jumping Sideways  \
# path                                       -0.012797
# time                                       -0.044825
# force_input_raw_y                           0.157906
# force_input_raw_x                          -0.003082
# ppi                                        -0.038397
# robot_pose_z                                0.043332
# robotrainer_deviation_left                  0.083522
# robot_pose_y                               -0.096087
# output_data_linear_z                       -0.287836
# velocity_output_angular_z                  -0.027490
# output_data_linear_x                       -0.003102
# virtual_force_resulting_force_y            -0.045891
# virtual_force_resulting_force_x             0.034720
# output_data_angular_y                       0.279598
# output_data_angular_z                       0.052033
# heart_rate                                  0.042583
# virtual_force_position_x                   -0.045879
# virtual_force_position_y                   -0.075042
# virtual_force_velocity_out_y                0.131195
# virtual_force_velocity_out_x                0.028112
# force_input_scaled_limited_y                0.164167
# force_input_scaled_limited_x                0.050119
# torque_input_scaled_limited_z               0.063709
# virtual_force_resulting_velocity_x          0.035842
# virtual_force_resulting_velocity_y         -0.046770
# virtual_force_velocity_in_y                 0.206059
# virtual_force_velocity_in_x                 0.026137
# velocity_output_linear_x                    0.038581
# velocity_output_linear_y                    0.120332
# torque_input_raw_z                          0.052234
# robotrainer_deviation_right                -0.203297
# robotrainer_deviation_front                -0.107169
# robot_pose_x                                0.015674
# total_duration                             -0.044810
# age_x                                      -0.420908
# age_y                                      -0.420908
# Balance Test                                0.657172
# Single Leg Stance                          -0.620668
# Robotrainer Front                          -0.174730
# Robotrainer Left                           -0.041196
# Robotrainer Right                          -0.050112
# Hand Grip Left                             -0.013098
# Hand Grip Right                             0.008247
# Jump & Reach                                0.269363
# Tandem Walk                                -0.177755
# Figure 8 Walk                              -0.524510
# Jumping Sideways                            1.000000
# Throwing Beanbag at Target                  0.125778
# Tapping Test                               -0.326852
# Ruler Drop Test                            -0.379566
#
# ID                                  Throwing Beanbag at Target  Tapping Test  \
# path                                                  0.004856     -0.000558
# time                                                 -0.025259      0.045907
# force_input_raw_y                                     0.110775      0.015960
# force_input_raw_x                                     0.087250     -0.101636
# ppi                                                  -0.005909      0.132743
# robot_pose_z                                         -0.008018      0.005761
# robotrainer_deviation_left                            0.097203     -0.033702
# robot_pose_y                                         -0.040653      0.007598
# output_data_linear_z                                 -0.045566      0.111678
# velocity_output_angular_z                            -0.057439      0.013791
# output_data_linear_x                                  0.087162     -0.101892
# virtual_force_resulting_force_y                       0.003279     -0.009536
# virtual_force_resulting_force_x                       0.030167     -0.044889
# output_data_angular_y                                 0.028379     -0.096089
# output_data_angular_z                                 0.042485      0.033102
# heart_rate                                           -0.039078      0.011989
# virtual_force_position_x                             -0.028885     -0.041552
# virtual_force_position_y                             -0.027407     -0.005357
# virtual_force_velocity_out_y                          0.079961      0.013597
# virtual_force_velocity_out_x                          0.082641     -0.119402
# force_input_scaled_limited_y                          0.119327      0.014076
# force_input_scaled_limited_x                          0.063744     -0.105745
# torque_input_scaled_limited_z                         0.025479      0.033912
# virtual_force_resulting_velocity_x                    0.027968     -0.044369
# virtual_force_resulting_velocity_y                    0.003698     -0.009778
# virtual_force_velocity_in_y                           0.080692      0.035308
# virtual_force_velocity_in_x                           0.083409     -0.121066
# velocity_output_linear_x                              0.049373     -0.095518
# velocity_output_linear_y                              0.078228      0.012117
# torque_input_raw_z                                    0.044788      0.030114
# robotrainer_deviation_right                          -0.031068     -0.041113
# robotrainer_deviation_front                           0.065753     -0.099691
# robot_pose_x                                          0.024225     -0.039169
# total_duration                                       -0.025352      0.046446
# age_x                                                -0.220944      0.010571
# age_y                                                -0.220944      0.010571
# Balance Test                                          0.323320     -0.262258
# Single Leg Stance                                    -0.361669      0.269363
# Robotrainer Front                                     0.043711      0.035875
# Robotrainer Left                                     -0.177747      0.053993
# Robotrainer Right                                    -0.096660      0.026018
# Hand Grip Left                                       -0.174773      0.041955
# Hand Grip Right                                      -0.325467      0.205227
# Jump & Reach                                         -0.135443      0.303014
# Tandem Walk                                          -0.204962      0.145594
# Figure 8 Walk                                        -0.076518      0.061027
# Jumping Sideways                                      0.125778     -0.326852
# Throwing Beanbag at Target                            1.000000     -0.325867
# Tapping Test                                         -0.325867      1.000000
# Ruler Drop Test                                       0.244964     -0.114241
#
# ID                                  Ruler Drop Test
# path                                      -0.001490
# time                                       0.102865
# force_input_raw_y                         -0.071726
# force_input_raw_x                         -0.204157
# ppi                                       -0.181769
# robot_pose_z                              -0.029315
# robotrainer_deviation_left                -0.008462
# robot_pose_y                               0.053803
# output_data_linear_z                       0.136338
# velocity_output_angular_z                 -0.015715
# output_data_linear_x                      -0.204006
# virtual_force_resulting_force_y            0.027741
# virtual_force_resulting_force_x           -0.047968
# output_data_angular_y                     -0.105006
# output_data_angular_z                     -0.003186
# heart_rate                                 0.108634
# virtual_force_position_x                  -0.062899
# virtual_force_position_y                   0.083261
# virtual_force_velocity_out_y              -0.090778
# virtual_force_velocity_out_x              -0.177197
# force_input_scaled_limited_y              -0.068218
# force_input_scaled_limited_x              -0.154808
# torque_input_scaled_limited_z             -0.025226
# virtual_force_resulting_velocity_x        -0.049333
# virtual_force_resulting_velocity_y         0.028128
# virtual_force_velocity_in_y               -0.125309
# virtual_force_velocity_in_x               -0.187991
# velocity_output_linear_x                  -0.142500
# velocity_output_linear_y                  -0.077499
# torque_input_raw_z                        -0.001556
# robotrainer_deviation_right                0.076094
# robotrainer_deviation_front                0.001821
# robot_pose_x                              -0.107116
# total_duration                             0.102291
# age_x                                      0.510382
# age_y                                      0.510382
# Balance Test                              -0.444971
# Single Leg Stance                          0.357447
# Robotrainer Front                         -0.209271
# Robotrainer Left                          -0.251914
# Robotrainer Right                         -0.303290
# Hand Grip Left                            -0.201732
# Hand Grip Right                           -0.136038
# Jump & Reach                              -0.610479
# Tandem Walk                               -0.345596
# Figure 8 Walk                              0.470184
# Jumping Sideways                          -0.379566
# Throwing Beanbag at Target                 0.244964
# Tapping Test                              -0.114241
# Ruler Drop Test                            1.000000

# %%
plt.figure(figsize=(12, max(6, len(num_df.columns)*0.3)))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="Reds")
plt.title("Korrelation Robotrainer-Features vs Ground Truth")
plt.tight_layout()

plt.savefig('figures/pearson.pdf', format='pdf')

plt.show()

# %% [markdown]
# ### Spearman

# %%
corr_matrix_spearman = num_df.corr(method="spearman").loc[:, gt_cols]
print("Korrelationsmatrix:")
print(corr_matrix)
# Out:
# Korrelationsmatrix:
# ID                                  Balance Test  Single Leg Stance  \
# path                                   -0.003351           0.000142
# time                                   -0.048059           0.035348
# force_input_raw_y                       0.240490          -0.082010
# force_input_raw_x                       0.116833          -0.062583
# ppi                                     0.021777           0.079427
# robot_pose_z                            0.035635          -0.001432
# robotrainer_deviation_left              0.091071          -0.172007
# robot_pose_y                           -0.118918           0.091906
# output_data_linear_z                   -0.190562           0.195889
# velocity_output_angular_z              -0.029933           0.050965
# output_data_linear_x                    0.116905          -0.062329
# virtual_force_resulting_force_y        -0.046251          -0.007227
# virtual_force_resulting_force_x         0.036811          -0.014163
# output_data_angular_y                   0.164805          -0.181899
# output_data_angular_z                   0.061360           0.001394
# heart_rate                             -0.029380          -0.021714
# virtual_force_position_x                0.089237           0.196327
# virtual_force_position_y               -0.146794           0.044761
# virtual_force_velocity_out_y            0.201869          -0.095113
# virtual_force_velocity_out_x            0.150019          -0.004238
# force_input_scaled_limited_y            0.248530          -0.098401
# force_input_scaled_limited_x            0.125821          -0.052996
# torque_input_scaled_limited_z           0.054857          -0.021092
# virtual_force_resulting_velocity_x      0.037044          -0.013078
# virtual_force_resulting_velocity_y     -0.046500          -0.006936
# virtual_force_velocity_in_y             0.256898          -0.094153
# virtual_force_velocity_in_x             0.157206          -0.003495
# velocity_output_linear_x                0.104399          -0.012988
# velocity_output_linear_y                0.197163          -0.091028
# torque_input_raw_z                      0.061831           0.001830
# robotrainer_deviation_right            -0.164089           0.238063
# robotrainer_deviation_front            -0.033655           0.144606
# robot_pose_x                            0.121829           0.079936
# total_duration                         -0.047994           0.035747
# age_x                                  -0.397362           0.593531
# age_y                                  -0.397362           0.593531
# Balance Test                            1.000000          -0.442672
# Single Leg Stance                      -0.442672           1.000000
# Robotrainer Front                       0.060091           0.188538
# Robotrainer Left                        0.141512           0.020057
# Robotrainer Right                       0.101352          -0.003826
# Hand Grip Left                          0.100830           0.073906
# Hand Grip Right                        -0.012873           0.105628
# Jump & Reach                            0.474169          -0.323765
# Tandem Walk                            -0.209543           0.014955
# Figure 8 Walk                          -0.586732           0.330744
# Jumping Sideways                        0.657172          -0.620668
# Throwing Beanbag at Target              0.323320          -0.361669
# Tapping Test                           -0.262258           0.269363
# Ruler Drop Test                        -0.444971           0.357447
#
# ID                                  Robotrainer Front  Robotrainer Left  \
# path                                         0.021275          0.017964
# time                                        -0.137165         -0.065853
# force_input_raw_y                            0.008814          0.155692
# force_input_raw_x                            0.282776          0.229008
# ppi                                          0.089826         -0.026279
# robot_pose_z                                 0.017302          0.026194
# robotrainer_deviation_left                  -0.021311          0.038315
# robot_pose_y                                -0.022353         -0.107278
# output_data_linear_z                         0.248704          0.210010
# velocity_output_angular_z                    0.054102         -0.037101
# output_data_linear_x                         0.282997          0.229075
# virtual_force_resulting_force_y             -0.000631         -0.024253
# virtual_force_resulting_force_x              0.198608          0.090649
# output_data_angular_y                       -0.281825         -0.241865
# output_data_angular_z                       -0.070612         -0.012506
# heart_rate                                   0.071985          0.048550
# virtual_force_position_x                     0.128366          0.122985
# virtual_force_position_y                    -0.045558         -0.125144
# virtual_force_velocity_out_y                -0.005101          0.130060
# virtual_force_velocity_out_x                 0.290099          0.227307
# force_input_scaled_limited_y                 0.003058          0.168589
# force_input_scaled_limited_x                 0.213174          0.173668
# torque_input_scaled_limited_z               -0.054863          0.015955
# virtual_force_resulting_velocity_x           0.197992          0.089615
# virtual_force_resulting_velocity_y           0.000070         -0.023750
# virtual_force_velocity_in_y                 -0.028530          0.133538
# virtual_force_velocity_in_x                  0.284766          0.233076
# velocity_output_linear_x                     0.215929          0.153074
# velocity_output_linear_y                    -0.000364          0.147938
# torque_input_raw_z                          -0.071905         -0.015135
# robotrainer_deviation_right                  0.060187         -0.078737
# robotrainer_deviation_front                  0.087263         -0.049113
# robot_pose_x                                 0.105068          0.097230
# total_duration                              -0.137223         -0.065128
# age_x                                        0.089096         -0.076335
# age_y                                        0.089096         -0.076335
# Balance Test                                 0.060091          0.141512
# Single Leg Stance                            0.188538          0.020057
# Robotrainer Front                            1.000000          0.641486
# Robotrainer Left                             0.641486          1.000000
# Robotrainer Right                            0.766309          0.876422
# Hand Grip Left                               0.671599          0.546169
# Hand Grip Right                              0.542791          0.637915
# Jump & Reach                                 0.106219          0.261807
# Tandem Walk                                 -0.106989         -0.047990
# Figure 8 Walk                               -0.134720         -0.366412
# Jumping Sideways                            -0.174730         -0.041196
# Throwing Beanbag at Target                   0.043711         -0.177747
# Tapping Test                                 0.035875          0.053993
# Ruler Drop Test                             -0.209271         -0.251914
#
# ID                                  Robotrainer Right  Hand Grip Left  \
# path                                         0.024247        0.022792
# time                                        -0.093990       -0.068935
# force_input_raw_y                            0.070327        0.011189
# force_input_raw_x                            0.299960        0.323081
# ppi                                         -0.001047       -0.097116
# robot_pose_z                                 0.008382        0.007397
# robotrainer_deviation_left                  -0.016808        0.023919
# robot_pose_y                                -0.056858       -0.060743
# output_data_linear_z                         0.237359        0.256199
# velocity_output_angular_z                   -0.002295        0.033939
# output_data_linear_x                         0.300071        0.323333
# virtual_force_resulting_force_y             -0.014745       -0.005659
# virtual_force_resulting_force_x              0.103874        0.209191
# output_data_angular_y                       -0.275463       -0.295279
# output_data_angular_z                       -0.052920       -0.067744
# heart_rate                                   0.169118        0.217024
# virtual_force_position_x                     0.134967        0.161574
# virtual_force_position_y                    -0.080355       -0.077919
# virtual_force_velocity_out_y                 0.058500        0.015199
# virtual_force_velocity_out_x                 0.285965        0.273991
# force_input_scaled_limited_y                 0.075487        0.007991
# force_input_scaled_limited_x                 0.216929        0.210008
# torque_input_scaled_limited_z               -0.022558       -0.063703
# virtual_force_resulting_velocity_x           0.103033        0.209333
# virtual_force_resulting_velocity_y          -0.014338       -0.005209
# virtual_force_velocity_in_y                  0.053976        0.004012
# virtual_force_velocity_in_x                  0.296392        0.266224
# velocity_output_linear_x                     0.196662        0.192163
# velocity_output_linear_y                     0.066206        0.031569
# torque_input_raw_z                          -0.056149       -0.068971
# robotrainer_deviation_right                 -0.014503       -0.003807
# robotrainer_deviation_front                 -0.014859        0.026327
# robot_pose_x                                 0.118739        0.141947
# total_duration                              -0.092890       -0.068460
# age_x                                       -0.144802        0.007797
# age_y                                       -0.144802        0.007797
# Balance Test                                 0.101352        0.100830
# Single Leg Stance                           -0.003826        0.073906
# Robotrainer Front                            0.766309        0.671599
# Robotrainer Left                             0.876422        0.546169
# Robotrainer Right                            1.000000        0.670293
# Hand Grip Left                               0.670293        1.000000
# Hand Grip Right                              0.711045        0.895836
# Jump & Reach                                 0.272528        0.379142
# Tandem Walk                                 -0.038097       -0.084345
# Figure 8 Walk                               -0.324500       -0.150366
# Jumping Sideways                            -0.050112       -0.013098
# Throwing Beanbag at Target                  -0.096660       -0.174773
# Tapping Test                                 0.026018        0.041955
# Ruler Drop Test                             -0.303290       -0.201732
#
# ID                                  Hand Grip Right  Jump & Reach  \
# path                                       0.020806      0.010206
# time                                      -0.035031     -0.017635
# force_input_raw_y                         -0.002009      0.128016
# force_input_raw_x                          0.240134      0.161658
# ppi                                       -0.106266      0.002932
# robot_pose_z                              -0.000427      0.017597
# robotrainer_deviation_left                -0.013030      0.077498
# robot_pose_y                              -0.044888     -0.099441
# output_data_linear_z                       0.276136     -0.017556
# velocity_output_angular_z                  0.018611     -0.031224
# output_data_linear_x                       0.240370      0.161327
# virtual_force_resulting_force_y           -0.014941     -0.015627
# virtual_force_resulting_force_x            0.127709      0.032474
# output_data_angular_y                     -0.303483     -0.008147
# output_data_angular_z                     -0.069232      0.018974
# heart_rate                                 0.226316     -0.036888
# virtual_force_position_x                   0.128196      0.096150
# virtual_force_position_y                  -0.061821     -0.119212
# virtual_force_velocity_out_y              -0.008874      0.133208
# virtual_force_velocity_out_x               0.204148      0.116389
# force_input_scaled_limited_y               0.001798      0.128442
# force_input_scaled_limited_x               0.157333      0.099949
# torque_input_scaled_limited_z             -0.055461      0.039521
# virtual_force_resulting_velocity_x         0.127792      0.033148
# virtual_force_resulting_velocity_y        -0.014728     -0.016057
# virtual_force_velocity_in_y               -0.005703      0.150734
# virtual_force_velocity_in_x                0.203936      0.122273
# velocity_output_linear_x                   0.136710      0.068604
# velocity_output_linear_y                   0.010200      0.138840
# torque_input_raw_z                        -0.071350      0.017809
# robotrainer_deviation_right               -0.032082     -0.109269
# robotrainer_deviation_front               -0.058714     -0.034808
# robot_pose_x                               0.099014      0.115818
# total_duration                            -0.034560     -0.015847
# age_x                                      0.039015     -0.445137
# age_y                                      0.039015     -0.445137
# Balance Test                              -0.012873      0.474169
# Single Leg Stance                          0.105628     -0.323765
# Robotrainer Front                          0.542791      0.106219
# Robotrainer Left                           0.637915      0.261807
# Robotrainer Right                          0.711045      0.272528
# Hand Grip Left                             0.895836      0.379142
# Hand Grip Right                            1.000000      0.370621
# Jump & Reach                               0.370621      1.000000
# Tandem Walk                               -0.036754     -0.041553
# Figure 8 Walk                             -0.178728     -0.461849
# Jumping Sideways                           0.008247      0.269363
# Throwing Beanbag at Target                -0.325467     -0.135443
# Tapping Test                               0.205227      0.303014
# Ruler Drop Test                           -0.136038     -0.610479
#
# ID                                  Tandem Walk  Figure 8 Walk  \
# path                                   0.003110       0.009026
# time                                  -0.019865       0.078442
# force_input_raw_y                     -0.069060      -0.178300
# force_input_raw_x                      0.115243      -0.085991
# ppi                                    0.289409       0.130387
# robot_pose_z                          -0.030167      -0.061238
# robotrainer_deviation_left            -0.081353      -0.053184
# robot_pose_y                           0.101744       0.152669
# output_data_linear_z                  -0.000247       0.166588
# velocity_output_angular_z             -0.005759       0.017950
# output_data_linear_x                   0.115237      -0.085831
# virtual_force_resulting_force_y        0.004020       0.048163
# virtual_force_resulting_force_x       -0.023938      -0.037936
# output_data_angular_y                 -0.015131      -0.149253
# output_data_angular_z                 -0.016718      -0.020807
# heart_rate                            -0.218075      -0.125453
# virtual_force_position_x               0.015205      -0.080824
# virtual_force_position_y               0.089819       0.183881
# virtual_force_velocity_out_y          -0.080118      -0.149418
# virtual_force_velocity_out_x           0.096399      -0.126581
# force_input_scaled_limited_y          -0.068924      -0.187851
# force_input_scaled_limited_x           0.053941      -0.118752
# torque_input_scaled_limited_z         -0.044104      -0.033965
# virtual_force_resulting_velocity_x    -0.024931      -0.038388
# virtual_force_resulting_velocity_y     0.003888       0.048131
# virtual_force_velocity_in_y           -0.080830      -0.210524
# virtual_force_velocity_in_x            0.111512      -0.132248
# velocity_output_linear_x               0.066829      -0.106650
# velocity_output_linear_y              -0.076951      -0.154090
# torque_input_raw_z                    -0.016674      -0.019519
# robotrainer_deviation_right            0.139451       0.198290
# robotrainer_deviation_front            0.081892       0.065331
# robot_pose_x                           0.004409      -0.105728
# total_duration                        -0.021429       0.077518
# age_x                                  0.086046       0.672675
# age_y                                  0.086046       0.672675
# Balance Test                          -0.209543      -0.586732
# Single Leg Stance                      0.014955       0.330744
# Robotrainer Front                     -0.106989      -0.134720
# Robotrainer Left                      -0.047990      -0.366412
# Robotrainer Right                     -0.038097      -0.324500
# Hand Grip Left                        -0.084345      -0.150366
# Hand Grip Right                       -0.036754      -0.178728
# Jump & Reach                          -0.041553      -0.461849
# Tandem Walk                            1.000000       0.259313
# Figure 8 Walk                          0.259313       1.000000
# Jumping Sideways                      -0.177755      -0.524510
# Throwing Beanbag at Target            -0.204962      -0.076518
# Tapping Test                           0.145594       0.061027
# Ruler Drop Test                       -0.345596       0.470184
#
# ID                                  Jumping Sideways  \
# path                                       -0.012797
# time                                       -0.044825
# force_input_raw_y                           0.157906
# force_input_raw_x                          -0.003082
# ppi                                        -0.038397
# robot_pose_z                                0.043332
# robotrainer_deviation_left                  0.083522
# robot_pose_y                               -0.096087
# output_data_linear_z                       -0.287836
# velocity_output_angular_z                  -0.027490
# output_data_linear_x                       -0.003102
# virtual_force_resulting_force_y            -0.045891
# virtual_force_resulting_force_x             0.034720
# output_data_angular_y                       0.279598
# output_data_angular_z                       0.052033
# heart_rate                                  0.042583
# virtual_force_position_x                   -0.045879
# virtual_force_position_y                   -0.075042
# virtual_force_velocity_out_y                0.131195
# virtual_force_velocity_out_x                0.028112
# force_input_scaled_limited_y                0.164167
# force_input_scaled_limited_x                0.050119
# torque_input_scaled_limited_z               0.063709
# virtual_force_resulting_velocity_x          0.035842
# virtual_force_resulting_velocity_y         -0.046770
# virtual_force_velocity_in_y                 0.206059
# virtual_force_velocity_in_x                 0.026137
# velocity_output_linear_x                    0.038581
# velocity_output_linear_y                    0.120332
# torque_input_raw_z                          0.052234
# robotrainer_deviation_right                -0.203297
# robotrainer_deviation_front                -0.107169
# robot_pose_x                                0.015674
# total_duration                             -0.044810
# age_x                                      -0.420908
# age_y                                      -0.420908
# Balance Test                                0.657172
# Single Leg Stance                          -0.620668
# Robotrainer Front                          -0.174730
# Robotrainer Left                           -0.041196
# Robotrainer Right                          -0.050112
# Hand Grip Left                             -0.013098
# Hand Grip Right                             0.008247
# Jump & Reach                                0.269363
# Tandem Walk                                -0.177755
# Figure 8 Walk                              -0.524510
# Jumping Sideways                            1.000000
# Throwing Beanbag at Target                  0.125778
# Tapping Test                               -0.326852
# Ruler Drop Test                            -0.379566
#
# ID                                  Throwing Beanbag at Target  Tapping Test  \
# path                                                  0.004856     -0.000558
# time                                                 -0.025259      0.045907
# force_input_raw_y                                     0.110775      0.015960
# force_input_raw_x                                     0.087250     -0.101636
# ppi                                                  -0.005909      0.132743
# robot_pose_z                                         -0.008018      0.005761
# robotrainer_deviation_left                            0.097203     -0.033702
# robot_pose_y                                         -0.040653      0.007598
# output_data_linear_z                                 -0.045566      0.111678
# velocity_output_angular_z                            -0.057439      0.013791
# output_data_linear_x                                  0.087162     -0.101892
# virtual_force_resulting_force_y                       0.003279     -0.009536
# virtual_force_resulting_force_x                       0.030167     -0.044889
# output_data_angular_y                                 0.028379     -0.096089
# output_data_angular_z                                 0.042485      0.033102
# heart_rate                                           -0.039078      0.011989
# virtual_force_position_x                             -0.028885     -0.041552
# virtual_force_position_y                             -0.027407     -0.005357
# virtual_force_velocity_out_y                          0.079961      0.013597
# virtual_force_velocity_out_x                          0.082641     -0.119402
# force_input_scaled_limited_y                          0.119327      0.014076
# force_input_scaled_limited_x                          0.063744     -0.105745
# torque_input_scaled_limited_z                         0.025479      0.033912
# virtual_force_resulting_velocity_x                    0.027968     -0.044369
# virtual_force_resulting_velocity_y                    0.003698     -0.009778
# virtual_force_velocity_in_y                           0.080692      0.035308
# virtual_force_velocity_in_x                           0.083409     -0.121066
# velocity_output_linear_x                              0.049373     -0.095518
# velocity_output_linear_y                              0.078228      0.012117
# torque_input_raw_z                                    0.044788      0.030114
# robotrainer_deviation_right                          -0.031068     -0.041113
# robotrainer_deviation_front                           0.065753     -0.099691
# robot_pose_x                                          0.024225     -0.039169
# total_duration                                       -0.025352      0.046446
# age_x                                                -0.220944      0.010571
# age_y                                                -0.220944      0.010571
# Balance Test                                          0.323320     -0.262258
# Single Leg Stance                                    -0.361669      0.269363
# Robotrainer Front                                     0.043711      0.035875
# Robotrainer Left                                     -0.177747      0.053993
# Robotrainer Right                                    -0.096660      0.026018
# Hand Grip Left                                       -0.174773      0.041955
# Hand Grip Right                                      -0.325467      0.205227
# Jump & Reach                                         -0.135443      0.303014
# Tandem Walk                                          -0.204962      0.145594
# Figure 8 Walk                                        -0.076518      0.061027
# Jumping Sideways                                      0.125778     -0.326852
# Throwing Beanbag at Target                            1.000000     -0.325867
# Tapping Test                                         -0.325867      1.000000
# Ruler Drop Test                                       0.244964     -0.114241
#
# ID                                  Ruler Drop Test
# path                                      -0.001490
# time                                       0.102865
# force_input_raw_y                         -0.071726
# force_input_raw_x                         -0.204157
# ppi                                       -0.181769
# robot_pose_z                              -0.029315
# robotrainer_deviation_left                -0.008462
# robot_pose_y                               0.053803
# output_data_linear_z                       0.136338
# velocity_output_angular_z                 -0.015715
# output_data_linear_x                      -0.204006
# virtual_force_resulting_force_y            0.027741
# virtual_force_resulting_force_x           -0.047968
# output_data_angular_y                     -0.105006
# output_data_angular_z                     -0.003186
# heart_rate                                 0.108634
# virtual_force_position_x                  -0.062899
# virtual_force_position_y                   0.083261
# virtual_force_velocity_out_y              -0.090778
# virtual_force_velocity_out_x              -0.177197
# force_input_scaled_limited_y              -0.068218
# force_input_scaled_limited_x              -0.154808
# torque_input_scaled_limited_z             -0.025226
# virtual_force_resulting_velocity_x        -0.049333
# virtual_force_resulting_velocity_y         0.028128
# virtual_force_velocity_in_y               -0.125309
# virtual_force_velocity_in_x               -0.187991
# velocity_output_linear_x                  -0.142500
# velocity_output_linear_y                  -0.077499
# torque_input_raw_z                        -0.001556
# robotrainer_deviation_right                0.076094
# robotrainer_deviation_front                0.001821
# robot_pose_x                              -0.107116
# total_duration                             0.102291
# age_x                                      0.510382
# age_y                                      0.510382
# Balance Test                              -0.444971
# Single Leg Stance                          0.357447
# Robotrainer Front                         -0.209271
# Robotrainer Left                          -0.251914
# Robotrainer Right                         -0.303290
# Hand Grip Left                            -0.201732
# Hand Grip Right                           -0.136038
# Jump & Reach                              -0.610479
# Tandem Walk                               -0.345596
# Figure 8 Walk                              0.470184
# Jumping Sideways                          -0.379566
# Throwing Beanbag at Target                 0.244964
# Tapping Test                              -0.114241
# Ruler Drop Test                            1.000000

# %%
plt.figure(figsize=(12, max(6, len(num_df.columns)*0.3)))
sns.heatmap(corr_matrix_spearman, annot=True, fmt=".2f", cmap="Reds")
plt.title("Korrelation Robotrainer-Features vs Ground Truth")
plt.tight_layout()

plt.savefig('figures/spearman.pdf', format='pdf')

plt.show()
